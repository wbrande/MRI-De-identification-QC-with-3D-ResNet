# %%
# train_resnet3d.ipynb starter (Python script format)

import os
import torch
import torch.nn as nn
import torch.optim as optim
import nibabel as nib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from My_3DResNet_Model import ResNet3D

# %%
# Dataset for 3D classification from .nii.gz files
class MRIDataset(Dataset):
    def __init__(self, image_paths, labels_df, label_column="facial_features_present", transform=None):
        self.image_paths = image_paths
        self.labels_df = labels_df
        self.label_column = label_column
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __tensorconversion__(self, idx):
        img_path = self.image_paths[idx]
        img = nib.load(img_path).get_fdata().astype(np.float32)
        img = (img - np.min(img)) / (np.max(img) - np.min(img) + 1e-8)  # normalize
        img = np.expand_dims(img, axis=0)  # [C, D, H, W]

        filename = os.path.basename(img_path).strip().lower()
        if filename not in self.labels_df.index:
            raise KeyError(f"Filename '{filename}' not found in labels DataFrame index. Sample index: {self.labels_df.index[:5].tolist()}")
        label_str = self.labels_df.loc[filename][self.label_column]
        label = 1.0 if str(label_str).strip().lower() in ['yes', '1', 'true'] else 0.0

        return torch.tensor(img), torch.tensor(label, dtype=torch.float32)

# %%
# Paths and file loading
image_dir = "../dataset/files"
label_csv = "../labels.csv"
labels_df = pd.read_csv(label_csv)

# Print column names and head for debugging
# print("CSV Columns:", labels_df.columns.tolist())
# print(labels_df.head())

# Normalize extensions and ensure matching index format
labels_df.iloc[:, 0] = labels_df.iloc[:, 0].astype(str).apply(lambda x: x.strip().lower().removesuffix('.nii').removesuffix('.gz') + '.nii.gz')
labels_df.set_index(labels_df.columns[0], inplace=True)

image_files = sorted([os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith(".nii.gz")])

# Dataset and DataLoader with validation and test split
from sklearn.model_selection import train_test_split

train_val_files, test_files = train_test_split(image_files, test_size=0.1, random_state=42)
train_files, val_files = train_test_split(train_val_files, test_size=0.2, random_state=42)

# For label classifier
label_column = "Recognizable-Facial-Feature" # "Recognizable-Facial-Feature", "Brain-Feature-Loss"

train_dataset = MRIDataset(train_files, labels_df, label_column=label_column)
val_dataset = MRIDataset(val_files, labels_df, label_column=label_column)
test_dataset = MRIDataset(test_files, labels_df, label_column=label_column)

train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Model setup
model = ResNet3D().cuda()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
# Training loop (multiple epochs with validation + tracking)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

n_epochs = 5
best_f1 = 0.0
train_history = []
val_history = []

for epoch in range(n_epochs):
    model.train()
    predictions = []
    targets = []
    running_loss = 0.0

    for i, (images, labels) in enumerate(train_loader):
        images = images.cuda()
        labels = labels.cuda()

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        preds = (outputs > 0.5).float()
        predictions.extend(preds.cpu().numpy())
        targets.extend(labels.cpu().numpy())

        running_loss += loss.item()
        print(f"Epoch [{epoch+1}/{n_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}", flush=True)

    train_acc = accuracy_score(targets, predictions)
    train_prec = precision_score(targets, predictions, zero_division=0)
    train_rec = recall_score(targets, predictions, zero_division=0)
    train_f1 = f1_score(targets, predictions, zero_division=0)
    train_history.append((train_acc, train_prec, train_rec, train_f1))

    # Validation metrics
    model.eval()
    val_preds = []
    val_targets = []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            labels = labels.cuda()
            outputs = model(images)
            preds = (outputs > 0.5).float()
            val_preds.extend(preds.cpu().numpy())
            val_targets.extend(labels.cpu().numpy())

    val_acc = accuracy_score(val_targets, val_preds)
    val_prec = precision_score(val_targets, val_preds, zero_division=0)
    val_rec = recall_score(val_targets, val_preds, zero_division=0)
    val_f1 = f1_score(val_targets, val_preds, zero_division=0)
    val_history.append((val_acc, val_prec, val_rec, val_f1))

    print(f"Validation Metrics [Epoch {epoch+1}]:Accuracy: {val_acc:.4f}, Precision: {val_prec:.4f}, Recall: {val_rec:.4f}, F1 Score: {val_f1:.4f}")
    
     # Save best model
    if val_f1 > best_f1:
        best_f1 = val_f1
        torch.save(model.state_dict(), "resnet3d_model.pt") # change depending on face features or brain tissue
        print(f"Best model saved at epoch {epoch+1} with F1 Score: {val_f1:.4f}")
# Out:
# Epoch [1/5], Step [1/1912], Loss: 0.5685
# Epoch [1/5], Step [2/1912], Loss: 0.4429
# Epoch [1/5], Step [3/1912], Loss: 0.3527
# Epoch [1/5], Step [4/1912], Loss: 0.1843
# Epoch [1/5], Step [5/1912], Loss: 0.1546
# Epoch [1/5], Step [6/1912], Loss: 0.7048
# Epoch [1/5], Step [7/1912], Loss: 0.3626
# Epoch [1/5], Step [8/1912], Loss: 1.4671
# Epoch [1/5], Step [9/1912], Loss: 0.4019
# Epoch [1/5], Step [10/1912], Loss: 0.3591
# Epoch [1/5], Step [11/1912], Loss: 0.1816
# Epoch [1/5], Step [12/1912], Loss: 0.3226
# Epoch [1/5], Step [13/1912], Loss: 0.2121
# Epoch [1/5], Step [14/1912], Loss: 0.2173
# Epoch [1/5], Step [15/1912], Loss: 0.6635
# Epoch [1/5], Step [16/1912], Loss: 0.1608
# Epoch [1/5], Step [17/1912], Loss: 0.1325
# Epoch [1/5], Step [18/1912], Loss: 0.1457
# Epoch [1/5], Step [19/1912], Loss: 0.2079
# Epoch [1/5], Step [20/1912], Loss: 0.1435
# Epoch [1/5], Step [21/1912], Loss: 0.1210
# Epoch [1/5], Step [22/1912], Loss: 0.0995
# Epoch [1/5], Step [23/1912], Loss: 0.1589
# Epoch [1/5], Step [24/1912], Loss: 0.1009
# Epoch [1/5], Step [25/1912], Loss: 0.0875
# Epoch [1/5], Step [26/1912], Loss: 0.3505
# Epoch [1/5], Step [27/1912], Loss: 0.0694
# Epoch [1/5], Step [28/1912], Loss: 0.0764
# Epoch [1/5], Step [29/1912], Loss: 0.2928
# Epoch [1/5], Step [30/1912], Loss: 0.1352
# Epoch [1/5], Step [31/1912], Loss: 0.0901
# Epoch [1/5], Step [32/1912], Loss: 0.0603
# Epoch [1/5], Step [33/1912], Loss: 0.1348
# Epoch [1/5], Step [34/1912], Loss: 0.0818
# Epoch [1/5], Step [35/1912], Loss: 0.0768
# Epoch [1/5], Step [36/1912], Loss: 0.1019
# Epoch [1/5], Step [37/1912], Loss: 0.0845
# Epoch [1/5], Step [38/1912], Loss: 0.1380
# Epoch [1/5], Step [39/1912], Loss: 3.0533
# Epoch [1/5], Step [40/1912], Loss: 0.3286
# Epoch [1/5], Step [41/1912], Loss: 1.7997
# Epoch [1/5], Step [42/1912], Loss: 0.0560
# Epoch [1/5], Step [43/1912], Loss: 0.0709
# Epoch [1/5], Step [44/1912], Loss: 0.9777
# Epoch [1/5], Step [45/1912], Loss: 0.0818
# Epoch [1/5], Step [46/1912], Loss: 0.0630
# Epoch [1/5], Step [47/1912], Loss: 0.3133
# Epoch [1/5], Step [48/1912], Loss: 0.7747
# Epoch [1/5], Step [49/1912], Loss: 0.0578
# Epoch [1/5], Step [50/1912], Loss: 0.1412
# Epoch [1/5], Step [51/1912], Loss: 0.0460
# Epoch [1/5], Step [52/1912], Loss: 0.0462
# Epoch [1/5], Step [53/1912], Loss: 0.4992
# Epoch [1/5], Step [54/1912], Loss: 0.7297
# Epoch [1/5], Step [55/1912], Loss: 0.0396
# Epoch [1/5], Step [56/1912], Loss: 2.0808
# Epoch [1/5], Step [57/1912], Loss: 0.0503
# Epoch [1/5], Step [58/1912], Loss: 0.8982
# Epoch [1/5], Step [59/1912], Loss: 0.0643
# Epoch [1/5], Step [60/1912], Loss: 0.3217
# Epoch [1/5], Step [61/1912], Loss: 0.1025
# Epoch [1/5], Step [62/1912], Loss: 0.3534
# Epoch [1/5], Step [63/1912], Loss: 0.1168
# Epoch [1/5], Step [64/1912], Loss: 1.2120
# Epoch [1/5], Step [65/1912], Loss: 0.1801
# Epoch [1/5], Step [66/1912], Loss: 0.2073
# Epoch [1/5], Step [67/1912], Loss: 0.7904
# Epoch [1/5], Step [68/1912], Loss: 0.2906
# Epoch [1/5], Step [69/1912], Loss: 1.0174
# Epoch [1/5], Step [70/1912], Loss: 0.2240
# Epoch [1/5], Step [71/1912], Loss: 0.5990
# Epoch [1/5], Step [72/1912], Loss: 0.1790
# Epoch [1/5], Step [73/1912], Loss: 0.1415
# Epoch [1/5], Step [74/1912], Loss: 0.0894
# Epoch [1/5], Step [75/1912], Loss: 0.0627
# Epoch [1/5], Step [76/1912], Loss: 1.4086
# Epoch [1/5], Step [77/1912], Loss: 0.2119
# Epoch [1/5], Step [78/1912], Loss: 0.1545
# Epoch [1/5], Step [79/1912], Loss: 0.0795
# Epoch [1/5], Step [80/1912], Loss: 2.1158
# Epoch [1/5], Step [81/1912], Loss: 0.1750
# Epoch [1/5], Step [82/1912], Loss: 0.1654
# Epoch [1/5], Step [83/1912], Loss: 0.0653
# Epoch [1/5], Step [84/1912], Loss: 0.0786
# Epoch [1/5], Step [85/1912], Loss: 0.1005
# Epoch [1/5], Step [86/1912], Loss: 0.0724
# Epoch [1/5], Step [87/1912], Loss: 0.0956
# Epoch [1/5], Step [88/1912], Loss: 0.2176
# Epoch [1/5], Step [89/1912], Loss: 0.0714
# Epoch [1/5], Step [90/1912], Loss: 0.0720
# Epoch [1/5], Step [91/1912], Loss: 0.2118
# Epoch [1/5], Step [92/1912], Loss: 0.1087
# Epoch [1/5], Step [93/1912], Loss: 0.1081
# Epoch [1/5], Step [94/1912], Loss: 0.0705
# Epoch [1/5], Step [95/1912], Loss: 0.0992
# Epoch [1/5], Step [96/1912], Loss: 0.2151
# Epoch [1/5], Step [97/1912], Loss: 0.5578
# Epoch [1/5], Step [98/1912], Loss: 0.0927
# Epoch [1/5], Step [99/1912], Loss: 0.0874
# Epoch [1/5], Step [100/1912], Loss: 0.1296
# Epoch [1/5], Step [101/1912], Loss: 0.2324
# Epoch [1/5], Step [102/1912], Loss: 0.0815
# Epoch [1/5], Step [103/1912], Loss: 0.0595
# Epoch [1/5], Step [104/1912], Loss: 1.2686
# Epoch [1/5], Step [105/1912], Loss: 0.0514
# Epoch [1/5], Step [106/1912], Loss: 0.0418
# Epoch [1/5], Step [107/1912], Loss: 0.0481
# Epoch [1/5], Step [108/1912], Loss: 0.0585
# Epoch [1/5], Step [109/1912], Loss: 0.0702
# Epoch [1/5], Step [110/1912], Loss: 0.0528
# Epoch [1/5], Step [111/1912], Loss: 0.0482
# Epoch [1/5], Step [112/1912], Loss: 0.0452
# Epoch [1/5], Step [113/1912], Loss: 2.2744
# Epoch [1/5], Step [114/1912], Loss: 0.0530
# Epoch [1/5], Step [115/1912], Loss: 1.6307
# Epoch [1/5], Step [116/1912], Loss: 0.0512
# Epoch [1/5], Step [117/1912], Loss: 0.0539
# Epoch [1/5], Step [118/1912], Loss: 0.0532
# Epoch [1/5], Step [119/1912], Loss: 0.0757
# Epoch [1/5], Step [120/1912], Loss: 0.0513
# Epoch [1/5], Step [121/1912], Loss: 0.2949
# Epoch [1/5], Step [122/1912], Loss: 0.0811
# Epoch [1/5], Step [123/1912], Loss: 0.2281
# Epoch [1/5], Step [124/1912], Loss: 0.1272
# Epoch [1/5], Step [125/1912], Loss: 0.1318
# Epoch [1/5], Step [126/1912], Loss: 0.2597
# Epoch [1/5], Step [127/1912], Loss: 0.0663
# Epoch [1/5], Step [128/1912], Loss: 0.2191
# Epoch [1/5], Step [129/1912], Loss: 0.0660
# Epoch [1/5], Step [130/1912], Loss: 1.8750
# Epoch [1/5], Step [131/1912], Loss: 0.2984
# Epoch [1/5], Step [132/1912], Loss: 0.0510
# Epoch [1/5], Step [133/1912], Loss: 0.2011
# Epoch [1/5], Step [134/1912], Loss: 0.0415
# Epoch [1/5], Step [135/1912], Loss: 0.0448
# Epoch [1/5], Step [136/1912], Loss: 0.2138
# Epoch [1/5], Step [137/1912], Loss: 0.3349
# Epoch [1/5], Step [138/1912], Loss: 0.2787
# Epoch [1/5], Step [139/1912], Loss: 0.2126
# Epoch [1/5], Step [140/1912], Loss: 0.0476
# Epoch [1/5], Step [141/1912], Loss: 0.0829
# Epoch [1/5], Step [142/1912], Loss: 0.4426
# Epoch [1/5], Step [143/1912], Loss: 0.0487
# Epoch [1/5], Step [144/1912], Loss: 0.0308
# Epoch [1/5], Step [145/1912], Loss: 0.0465
# Epoch [1/5], Step [146/1912], Loss: 0.0250
# Epoch [1/5], Step [147/1912], Loss: 0.7284
# Epoch [1/5], Step [148/1912], Loss: 0.0390
# Epoch [1/5], Step [149/1912], Loss: 0.0377
# Epoch [1/5], Step [150/1912], Loss: 0.0303
# Epoch [1/5], Step [151/1912], Loss: 0.0472
# Epoch [1/5], Step [152/1912], Loss: 0.1448
# Epoch [1/5], Step [153/1912], Loss: 0.0280
# Epoch [1/5], Step [154/1912], Loss: 0.3431
# Epoch [1/5], Step [155/1912], Loss: 0.1678
# Epoch [1/5], Step [156/1912], Loss: 0.0353
# Epoch [1/5], Step [157/1912], Loss: 0.0266
# Epoch [1/5], Step [158/1912], Loss: 0.1074
# Epoch [1/5], Step [159/1912], Loss: 0.0568
# Epoch [1/5], Step [160/1912], Loss: 0.0246
# Epoch [1/5], Step [161/1912], Loss: 0.0751
# Epoch [1/5], Step [162/1912], Loss: 0.7081
# Epoch [1/5], Step [163/1912], Loss: 0.1074
# Epoch [1/5], Step [164/1912], Loss: 0.1560
# Epoch [1/5], Step [165/1912], Loss: 0.0261
# Epoch [1/5], Step [166/1912], Loss: 0.0221
# Epoch [1/5], Step [167/1912], Loss: 0.1522
# Epoch [1/5], Step [168/1912], Loss: 0.0246
# Epoch [1/5], Step [169/1912], Loss: 0.0228
# Epoch [1/5], Step [170/1912], Loss: 0.2402
# Epoch [1/5], Step [171/1912], Loss: 0.0226
# Epoch [1/5], Step [172/1912], Loss: 0.0218
# Epoch [1/5], Step [173/1912], Loss: 0.1029
# Epoch [1/5], Step [174/1912], Loss: 0.0217
# Epoch [1/5], Step [175/1912], Loss: 0.1319
# Epoch [1/5], Step [176/1912], Loss: 0.0680
# Epoch [1/5], Step [177/1912], Loss: 1.9454
# Epoch [1/5], Step [178/1912], Loss: 0.0193
# Epoch [1/5], Step [179/1912], Loss: 0.0243
# Epoch [1/5], Step [180/1912], Loss: 0.0213
# Epoch [1/5], Step [181/1912], Loss: 0.0185
# Epoch [1/5], Step [182/1912], Loss: 0.0810
# Epoch [1/5], Step [183/1912], Loss: 0.2757
# Epoch [1/5], Step [184/1912], Loss: 0.0161
# Epoch [1/5], Step [185/1912], Loss: 0.4978
# Epoch [1/5], Step [186/1912], Loss: 0.0320
# Epoch [1/5], Step [187/1912], Loss: 0.4120
# Epoch [1/5], Step [188/1912], Loss: 0.2874
# Epoch [1/5], Step [189/1912], Loss: 0.0349
# Epoch [1/5], Step [190/1912], Loss: 0.0414
# Epoch [1/5], Step [191/1912], Loss: 0.0735
# Epoch [1/5], Step [192/1912], Loss: 0.0204
# Epoch [1/5], Step [193/1912], Loss: 0.1304
# Epoch [1/5], Step [194/1912], Loss: 0.0477
# Epoch [1/5], Step [195/1912], Loss: 0.0357
# Epoch [1/5], Step [196/1912], Loss: 0.2382
# Epoch [1/5], Step [197/1912], Loss: 0.2344
# Epoch [1/5], Step [198/1912], Loss: 0.0267
# Epoch [1/5], Step [199/1912], Loss: 0.0321
# Epoch [1/5], Step [200/1912], Loss: 0.0406
# Epoch [1/5], Step [201/1912], Loss: 2.9471
# Epoch [1/5], Step [202/1912], Loss: 0.0712
# Epoch [1/5], Step [203/1912], Loss: 0.0494
# Epoch [1/5], Step [204/1912], Loss: 0.0255
# Epoch [1/5], Step [205/1912], Loss: 0.0376
# Epoch [1/5], Step [206/1912], Loss: 0.0224
# Epoch [1/5], Step [207/1912], Loss: 0.0758
# Epoch [1/5], Step [208/1912], Loss: 0.0187
# Epoch [1/5], Step [209/1912], Loss: 0.1493
# Epoch [1/5], Step [210/1912], Loss: 0.0869
# Epoch [1/5], Step [211/1912], Loss: 0.0203
# Epoch [1/5], Step [212/1912], Loss: 0.0184
# Epoch [1/5], Step [213/1912], Loss: 0.0847
# Epoch [1/5], Step [214/1912], Loss: 0.0259
# Epoch [1/5], Step [215/1912], Loss: 0.0164
# Epoch [1/5], Step [216/1912], Loss: 0.0694
# Epoch [1/5], Step [217/1912], Loss: 0.0230
# Epoch [1/5], Step [218/1912], Loss: 0.0208
# Epoch [1/5], Step [219/1912], Loss: 0.0154
# Epoch [1/5], Step [220/1912], Loss: 0.8269
# Epoch [1/5], Step [221/1912], Loss: 0.3179
# Epoch [1/5], Step [222/1912], Loss: 0.0453
# Epoch [1/5], Step [223/1912], Loss: 0.0275
# Epoch [1/5], Step [224/1912], Loss: 0.0795
# Epoch [1/5], Step [225/1912], Loss: 0.0244
# Epoch [1/5], Step [226/1912], Loss: 0.0275
# Epoch [1/5], Step [227/1912], Loss: 0.0411
# Epoch [1/5], Step [228/1912], Loss: 0.0615
# Epoch [1/5], Step [229/1912], Loss: 0.0701
# Epoch [1/5], Step [230/1912], Loss: 0.1650
# Epoch [1/5], Step [231/1912], Loss: 2.8095
# Epoch [1/5], Step [232/1912], Loss: 0.0385
# Epoch [1/5], Step [233/1912], Loss: 0.1921
# Epoch [1/5], Step [234/1912], Loss: 0.0232
# Epoch [1/5], Step [235/1912], Loss: 0.0157
# Epoch [1/5], Step [236/1912], Loss: 0.0184
# Epoch [1/5], Step [237/1912], Loss: 0.1661
# Epoch [1/5], Step [238/1912], Loss: 0.3435
# Epoch [1/5], Step [239/1912], Loss: 0.0153
# Epoch [1/5], Step [240/1912], Loss: 1.6490
# Epoch [1/5], Step [241/1912], Loss: 0.0147
# Epoch [1/5], Step [242/1912], Loss: 0.0331
# Epoch [1/5], Step [243/1912], Loss: 0.0203
# Epoch [1/5], Step [244/1912], Loss: 0.0145
# Epoch [1/5], Step [245/1912], Loss: 0.8398
# Epoch [1/5], Step [246/1912], Loss: 0.3901
# Epoch [1/5], Step [247/1912], Loss: 1.1256
# Epoch [1/5], Step [248/1912], Loss: 0.0738
# Epoch [1/5], Step [249/1912], Loss: 0.4437
# Epoch [1/5], Step [250/1912], Loss: 0.0149
# Epoch [1/5], Step [251/1912], Loss: 0.7965
# Epoch [1/5], Step [252/1912], Loss: 0.3279
# Epoch [1/5], Step [253/1912], Loss: 0.2837
# Epoch [1/5], Step [254/1912], Loss: 0.0211
# Epoch [1/5], Step [255/1912], Loss: 0.1853
# Epoch [1/5], Step [256/1912], Loss: 0.1822
# Epoch [1/5], Step [257/1912], Loss: 0.0991
# Epoch [1/5], Step [258/1912], Loss: 0.0219
# Epoch [1/5], Step [259/1912], Loss: 0.0396
# Epoch [1/5], Step [260/1912], Loss: 0.1063
# Epoch [1/5], Step [261/1912], Loss: 0.0857
# Epoch [1/5], Step [262/1912], Loss: 0.4817
# Epoch [1/5], Step [263/1912], Loss: 0.0589
# Epoch [1/5], Step [264/1912], Loss: 0.0857
# Epoch [1/5], Step [265/1912], Loss: 0.0203
# Epoch [1/5], Step [266/1912], Loss: 0.0607
# Epoch [1/5], Step [267/1912], Loss: 0.0298
# Epoch [1/5], Step [268/1912], Loss: 0.0181
# Epoch [1/5], Step [269/1912], Loss: 0.0597
# Epoch [1/5], Step [270/1912], Loss: 0.0207
# Epoch [1/5], Step [271/1912], Loss: 0.0247
# Epoch [1/5], Step [272/1912], Loss: 0.0193
# Epoch [1/5], Step [273/1912], Loss: 0.0294
# Epoch [1/5], Step [274/1912], Loss: 0.0217
# Epoch [1/5], Step [275/1912], Loss: 0.1094
# Epoch [1/5], Step [276/1912], Loss: 0.0203
# Epoch [1/5], Step [277/1912], Loss: 0.2610
# Epoch [1/5], Step [278/1912], Loss: 0.0189
# Epoch [1/5], Step [279/1912], Loss: 0.0178
# Epoch [1/5], Step [280/1912], Loss: 3.6202
# Epoch [1/5], Step [281/1912], Loss: 0.0189
# Epoch [1/5], Step [282/1912], Loss: 0.4930
# Epoch [1/5], Step [283/1912], Loss: 0.0239
# Epoch [1/5], Step [284/1912], Loss: 2.0088
# Epoch [1/5], Step [285/1912], Loss: 1.6653
# Epoch [1/5], Step [286/1912], Loss: 1.5999
# Epoch [1/5], Step [287/1912], Loss: 0.0282
# Epoch [1/5], Step [288/1912], Loss: 0.2655
# Epoch [1/5], Step [289/1912], Loss: 0.5298
# Epoch [1/5], Step [290/1912], Loss: 2.4875
# Epoch [1/5], Step [291/1912], Loss: 0.3792
# Epoch [1/5], Step [292/1912], Loss: 0.0383
# Epoch [1/5], Step [293/1912], Loss: 0.0827
# Epoch [1/5], Step [294/1912], Loss: 0.4899
# Epoch [1/5], Step [295/1912], Loss: 0.3785
# Epoch [1/5], Step [296/1912], Loss: 0.2822
# Epoch [1/5], Step [297/1912], Loss: 0.2521
# Epoch [1/5], Step [298/1912], Loss: 0.1716
# Epoch [1/5], Step [299/1912], Loss: 1.7960
# Epoch [1/5], Step [300/1912], Loss: 0.1435
# Epoch [1/5], Step [301/1912], Loss: 0.1581
# Epoch [1/5], Step [302/1912], Loss: 0.1882
# Epoch [1/5], Step [303/1912], Loss: 0.3484
# Epoch [1/5], Step [304/1912], Loss: 0.0612
# Epoch [1/5], Step [305/1912], Loss: 0.0528
# Epoch [1/5], Step [306/1912], Loss: 0.2941
# Epoch [1/5], Step [307/1912], Loss: 0.0497
# Epoch [1/5], Step [308/1912], Loss: 0.0549
# Epoch [1/5], Step [309/1912], Loss: 0.1989
# Epoch [1/5], Step [310/1912], Loss: 0.0503
# Epoch [1/5], Step [311/1912], Loss: 0.1964
# Epoch [1/5], Step [312/1912], Loss: 0.0467
# Epoch [1/5], Step [313/1912], Loss: 0.0673
# Epoch [1/5], Step [314/1912], Loss: 0.2804
# Epoch [1/5], Step [315/1912], Loss: 0.2532
# Epoch [1/5], Step [316/1912], Loss: 0.0414
# Epoch [1/5], Step [317/1912], Loss: 0.0445
# Epoch [1/5], Step [318/1912], Loss: 0.1017
# Epoch [1/5], Step [319/1912], Loss: 0.0428
# Epoch [1/5], Step [320/1912], Loss: 0.0834
# Epoch [1/5], Step [321/1912], Loss: 0.0364
# Epoch [1/5], Step [322/1912], Loss: 0.0423
# Epoch [1/5], Step [323/1912], Loss: 0.0659
# Epoch [1/5], Step [324/1912], Loss: 0.0384
# Epoch [1/5], Step [325/1912], Loss: 0.0504
# Epoch [1/5], Step [326/1912], Loss: 0.0362
# Epoch [1/5], Step [327/1912], Loss: 0.0791
# Epoch [1/5], Step [328/1912], Loss: 0.0339
# Epoch [1/5], Step [329/1912], Loss: 0.2211
# Epoch [1/5], Step [330/1912], Loss: 0.1374
# Epoch [1/5], Step [331/1912], Loss: 1.5474
# Epoch [1/5], Step [332/1912], Loss: 0.0709
# Epoch [1/5], Step [333/1912], Loss: 0.1765
# Epoch [1/5], Step [334/1912], Loss: 0.0649
# Epoch [1/5], Step [335/1912], Loss: 0.0421
# Epoch [1/5], Step [336/1912], Loss: 0.0540
# Epoch [1/5], Step [337/1912], Loss: 0.0462
# Epoch [1/5], Step [338/1912], Loss: 0.8751
# Epoch [1/5], Step [339/1912], Loss: 0.0401
# Epoch [1/5], Step [340/1912], Loss: 0.0469
# Epoch [1/5], Step [341/1912], Loss: 0.0409
# Epoch [1/5], Step [342/1912], Loss: 0.0607
# Epoch [1/5], Step [343/1912], Loss: 0.0394
# Epoch [1/5], Step [344/1912], Loss: 0.0375
# Epoch [1/5], Step [345/1912], Loss: 0.0432
# Epoch [1/5], Step [346/1912], Loss: 0.0405
# Epoch [1/5], Step [347/1912], Loss: 0.0531
# Epoch [1/5], Step [348/1912], Loss: 0.0369
# Epoch [1/5], Step [349/1912], Loss: 0.0338
# Epoch [1/5], Step [350/1912], Loss: 0.0364
# Epoch [1/5], Step [351/1912], Loss: 0.0454
# Epoch [1/5], Step [352/1912], Loss: 0.0352
# Epoch [1/5], Step [353/1912], Loss: 0.0390
# Epoch [1/5], Step [354/1912], Loss: 0.0313
# Epoch [1/5], Step [355/1912], Loss: 0.0284
# Epoch [1/5], Step [356/1912], Loss: 0.0440
# Epoch [1/5], Step [357/1912], Loss: 0.0482
# Epoch [1/5], Step [358/1912], Loss: 0.0494
# Epoch [1/5], Step [359/1912], Loss: 0.0257
# Epoch [1/5], Step [360/1912], Loss: 0.0279
# Epoch [1/5], Step [361/1912], Loss: 0.0384
# Epoch [1/5], Step [362/1912], Loss: 0.0278
# Epoch [1/5], Step [363/1912], Loss: 0.0298
# Epoch [1/5], Step [364/1912], Loss: 0.0371
# Epoch [1/5], Step [365/1912], Loss: 0.5914
# Epoch [1/5], Step [366/1912], Loss: 0.0244
# Epoch [1/5], Step [367/1912], Loss: 0.0270
# Epoch [1/5], Step [368/1912], Loss: 0.0491
# Epoch [1/5], Step [369/1912], Loss: 0.0330
# Epoch [1/5], Step [370/1912], Loss: 0.4857
# Epoch [1/5], Step [371/1912], Loss: 0.5050
# Epoch [1/5], Step [372/1912], Loss: 0.1173
# Epoch [1/5], Step [373/1912], Loss: 0.0278
# Epoch [1/5], Step [374/1912], Loss: 0.2756
# Epoch [1/5], Step [375/1912], Loss: 0.0249
# Epoch [1/5], Step [376/1912], Loss: 0.0385
# Epoch [1/5], Step [377/1912], Loss: 0.0427
# Epoch [1/5], Step [378/1912], Loss: 0.0226
# Epoch [1/5], Step [379/1912], Loss: 0.3479
# Epoch [1/5], Step [380/1912], Loss: 0.0278
# Epoch [1/5], Step [381/1912], Loss: 0.0180
# Epoch [1/5], Step [382/1912], Loss: 0.0851
# Epoch [1/5], Step [383/1912], Loss: 0.2421
# Epoch [1/5], Step [384/1912], Loss: 0.0176
# Epoch [1/5], Step [385/1912], Loss: 0.0259
# Epoch [1/5], Step [386/1912], Loss: 0.0612
# Epoch [1/5], Step [387/1912], Loss: 0.0357
# Epoch [1/5], Step [388/1912], Loss: 0.0169
# Epoch [1/5], Step [389/1912], Loss: 0.0190
# Epoch [1/5], Step [390/1912], Loss: 0.1500
# Epoch [1/5], Step [391/1912], Loss: 0.0346
# Epoch [1/5], Step [392/1912], Loss: 0.0176
# Epoch [1/5], Step [393/1912], Loss: 2.2258
# Epoch [1/5], Step [394/1912], Loss: 0.0234
# Epoch [1/5], Step [395/1912], Loss: 0.0192
# Epoch [1/5], Step [396/1912], Loss: 0.0184
# Epoch [1/5], Step [397/1912], Loss: 0.0286
# Epoch [1/5], Step [398/1912], Loss: 0.0178
# Epoch [1/5], Step [399/1912], Loss: 0.3188
# Epoch [1/5], Step [400/1912], Loss: 0.3475
# Epoch [1/5], Step [401/1912], Loss: 0.4381
# Epoch [1/5], Step [402/1912], Loss: 0.0177
# Epoch [1/5], Step [403/1912], Loss: 0.3041
# Epoch [1/5], Step [404/1912], Loss: 0.0181
# Epoch [1/5], Step [405/1912], Loss: 0.0196
# Epoch [1/5], Step [406/1912], Loss: 0.0203
# Epoch [1/5], Step [407/1912], Loss: 2.3610
# Epoch [1/5], Step [408/1912], Loss: 0.0250
# Epoch [1/5], Step [409/1912], Loss: 0.0197
# Epoch [1/5], Step [410/1912], Loss: 0.0793
# Epoch [1/5], Step [411/1912], Loss: 0.0185
# Epoch [1/5], Step [412/1912], Loss: 0.1760
# Epoch [1/5], Step [413/1912], Loss: 0.0233
# Epoch [1/5], Step [414/1912], Loss: 0.1544
# Epoch [1/5], Step [415/1912], Loss: 0.0163
# Epoch [1/5], Step [416/1912], Loss: 0.0281
# Epoch [1/5], Step [417/1912], Loss: 0.0244
# Epoch [1/5], Step [418/1912], Loss: 0.1984
# Epoch [1/5], Step [419/1912], Loss: 0.1058
# Epoch [1/5], Step [420/1912], Loss: 0.0152
# Epoch [1/5], Step [421/1912], Loss: 0.0157
# Epoch [1/5], Step [422/1912], Loss: 0.0159
# Epoch [1/5], Step [423/1912], Loss: 0.0361
# Epoch [1/5], Step [424/1912], Loss: 0.0150
# Epoch [1/5], Step [425/1912], Loss: 0.0833
# Epoch [1/5], Step [426/1912], Loss: 0.0146
# Epoch [1/5], Step [427/1912], Loss: 1.6986
# Epoch [1/5], Step [428/1912], Loss: 0.0150
# Epoch [1/5], Step [429/1912], Loss: 0.1771
# Epoch [1/5], Step [430/1912], Loss: 0.1283
# Epoch [1/5], Step [431/1912], Loss: 0.2853
# Epoch [1/5], Step [432/1912], Loss: 0.0380
# Epoch [1/5], Step [433/1912], Loss: 0.0212
# Epoch [1/5], Step [434/1912], Loss: 0.0256
# Epoch [1/5], Step [435/1912], Loss: 0.0143
# Epoch [1/5], Step [436/1912], Loss: 0.2064
# Epoch [1/5], Step [437/1912], Loss: 0.5450
# Epoch [1/5], Step [438/1912], Loss: 0.0156
# Epoch [1/5], Step [439/1912], Loss: 0.4644
# Epoch [1/5], Step [440/1912], Loss: 0.1950
# Epoch [1/5], Step [441/1912], Loss: 0.0973
# Epoch [1/5], Step [442/1912], Loss: 0.0532
# Epoch [1/5], Step [443/1912], Loss: 0.0986
# Epoch [1/5], Step [444/1912], Loss: 2.0319
# Epoch [1/5], Step [445/1912], Loss: 0.2133
# Epoch [1/5], Step [446/1912], Loss: 0.0166
# Epoch [1/5], Step [447/1912], Loss: 0.2371
# Epoch [1/5], Step [448/1912], Loss: 0.0193
# Epoch [1/5], Step [449/1912], Loss: 0.0651
# Epoch [1/5], Step [450/1912], Loss: 0.0428
# Epoch [1/5], Step [451/1912], Loss: 0.0318
# Epoch [1/5], Step [452/1912], Loss: 0.3421
# Epoch [1/5], Step [453/1912], Loss: 2.1727
# Epoch [1/5], Step [454/1912], Loss: 1.9137
# Epoch [1/5], Step [455/1912], Loss: 0.0778
# Epoch [1/5], Step [456/1912], Loss: 0.3301
# Epoch [1/5], Step [457/1912], Loss: 0.0213
# Epoch [1/5], Step [458/1912], Loss: 0.0396
# Epoch [1/5], Step [459/1912], Loss: 0.6657
# Epoch [1/5], Step [460/1912], Loss: 0.0804
# Epoch [1/5], Step [461/1912], Loss: 0.2231
# Epoch [1/5], Step [462/1912], Loss: 0.1519
# Epoch [1/5], Step [463/1912], Loss: 0.0215
# Epoch [1/5], Step [464/1912], Loss: 2.0882
# Epoch [1/5], Step [465/1912], Loss: 0.0807
# Epoch [1/5], Step [466/1912], Loss: 0.4085
# Epoch [1/5], Step [467/1912], Loss: 0.0695
# Epoch [1/5], Step [468/1912], Loss: 0.0333
# Epoch [1/5], Step [469/1912], Loss: 0.0882
# Epoch [1/5], Step [470/1912], Loss: 0.1579
# Epoch [1/5], Step [471/1912], Loss: 0.1077
# Epoch [1/5], Step [472/1912], Loss: 0.0570
# Epoch [1/5], Step [473/1912], Loss: 0.0361
# Epoch [1/5], Step [474/1912], Loss: 0.0805
# Epoch [1/5], Step [475/1912], Loss: 0.0898
# Epoch [1/5], Step [476/1912], Loss: 0.1018
# Epoch [1/5], Step [477/1912], Loss: 0.0985
# Epoch [1/5], Step [478/1912], Loss: 0.1204
# Epoch [1/5], Step [479/1912], Loss: 0.0535
# Epoch [1/5], Step [480/1912], Loss: 0.9965
# Epoch [1/5], Step [481/1912], Loss: 0.0383
# Epoch [1/5], Step [482/1912], Loss: 0.0884
# Epoch [1/5], Step [483/1912], Loss: 0.0287
# Epoch [1/5], Step [484/1912], Loss: 0.1464
# Epoch [1/5], Step [485/1912], Loss: 0.0263
# Epoch [1/5], Step [486/1912], Loss: 0.0260
# Epoch [1/5], Step [487/1912], Loss: 0.1423
# Epoch [1/5], Step [488/1912], Loss: 0.0366
# Epoch [1/5], Step [489/1912], Loss: 0.1174
# Epoch [1/5], Step [490/1912], Loss: 0.0198
# Epoch [1/5], Step [491/1912], Loss: 0.0289
# Epoch [1/5], Step [492/1912], Loss: 0.0495
# Epoch [1/5], Step [493/1912], Loss: 0.6783
# Epoch [1/5], Step [494/1912], Loss: 0.0698
# Epoch [1/5], Step [495/1912], Loss: 0.0208
# Epoch [1/5], Step [496/1912], Loss: 0.2700
# Epoch [1/5], Step [497/1912], Loss: 0.0152
# Epoch [1/5], Step [498/1912], Loss: 0.0533
# Epoch [1/5], Step [499/1912], Loss: 0.0664
# Epoch [1/5], Step [500/1912], Loss: 0.0158
# Epoch [1/5], Step [501/1912], Loss: 0.0132
# Epoch [1/5], Step [502/1912], Loss: 0.0137
# Epoch [1/5], Step [503/1912], Loss: 0.0151
# Epoch [1/5], Step [504/1912], Loss: 0.6266
# Epoch [1/5], Step [505/1912], Loss: 0.0253
# Epoch [1/5], Step [506/1912], Loss: 0.1982
# Epoch [1/5], Step [507/1912], Loss: 0.0492
# Epoch [1/5], Step [508/1912], Loss: 0.0158
# Epoch [1/5], Step [509/1912], Loss: 0.0152
# Epoch [1/5], Step [510/1912], Loss: 0.0141
# Epoch [1/5], Step [511/1912], Loss: 0.0135
# Epoch [1/5], Step [512/1912], Loss: 0.0157
# Epoch [1/5], Step [513/1912], Loss: 0.0335
# Epoch [1/5], Step [514/1912], Loss: 1.0308
# Epoch [1/5], Step [515/1912], Loss: 0.1531
# Epoch [1/5], Step [516/1912], Loss: 0.0134
# Epoch [1/5], Step [517/1912], Loss: 0.1744
# Epoch [1/5], Step [518/1912], Loss: 0.2097
# Epoch [1/5], Step [519/1912], Loss: 0.0136
# Epoch [1/5], Step [520/1912], Loss: 0.0185
# Epoch [1/5], Step [521/1912], Loss: 0.1488
# Epoch [1/5], Step [522/1912], Loss: 0.0174
# Epoch [1/5], Step [523/1912], Loss: 1.1528
# Epoch [1/5], Step [524/1912], Loss: 0.0358
# Epoch [1/5], Step [525/1912], Loss: 0.0153
# Epoch [1/5], Step [526/1912], Loss: 0.0190
# Epoch [1/5], Step [527/1912], Loss: 1.0752
# Epoch [1/5], Step [528/1912], Loss: 0.0157
# Epoch [1/5], Step [529/1912], Loss: 0.0645
# Epoch [1/5], Step [530/1912], Loss: 0.0188
# Epoch [1/5], Step [531/1912], Loss: 0.0371
# Epoch [1/5], Step [532/1912], Loss: 0.0189
# Epoch [1/5], Step [533/1912], Loss: 0.0434
# Epoch [1/5], Step [534/1912], Loss: 0.0179
# Epoch [1/5], Step [535/1912], Loss: 0.0275
# Epoch [1/5], Step [536/1912], Loss: 0.0227
# Epoch [1/5], Step [537/1912], Loss: 0.0193
# Epoch [1/5], Step [538/1912], Loss: 0.0186
# Epoch [1/5], Step [539/1912], Loss: 0.0625
# Epoch [1/5], Step [540/1912], Loss: 0.0224
# Epoch [1/5], Step [541/1912], Loss: 0.0310
# Epoch [1/5], Step [542/1912], Loss: 0.0188
# Epoch [1/5], Step [543/1912], Loss: 0.0168
# Epoch [1/5], Step [544/1912], Loss: 0.0293
# Epoch [1/5], Step [545/1912], Loss: 0.0152
# Epoch [1/5], Step [546/1912], Loss: 0.0148
# Epoch [1/5], Step [547/1912], Loss: 0.0361
# Epoch [1/5], Step [548/1912], Loss: 0.0431
# Epoch [1/5], Step [549/1912], Loss: 0.0144
# Epoch [1/5], Step [550/1912], Loss: 0.0574
# Epoch [1/5], Step [551/1912], Loss: 0.0136
# Epoch [1/5], Step [552/1912], Loss: 0.0157
# Epoch [1/5], Step [553/1912], Loss: 0.0139
# Epoch [1/5], Step [554/1912], Loss: 0.0166
# Epoch [1/5], Step [555/1912], Loss: 0.0139
# Epoch [1/5], Step [556/1912], Loss: 1.7713
# Epoch [1/5], Step [557/1912], Loss: 0.0120
# Epoch [1/5], Step [558/1912], Loss: 0.0130
# Epoch [1/5], Step [559/1912], Loss: 0.0816
# Epoch [1/5], Step [560/1912], Loss: 0.0137
# Epoch [1/5], Step [561/1912], Loss: 0.0363
# Epoch [1/5], Step [562/1912], Loss: 0.1825
# Epoch [1/5], Step [563/1912], Loss: 0.5948
# Epoch [1/5], Step [564/1912], Loss: 0.0126
# Epoch [1/5], Step [565/1912], Loss: 0.3760
# Epoch [1/5], Step [566/1912], Loss: 0.0355
# Epoch [1/5], Step [567/1912], Loss: 0.0226
# Epoch [1/5], Step [568/1912], Loss: 0.0124
# Epoch [1/5], Step [569/1912], Loss: 0.0110
# Epoch [1/5], Step [570/1912], Loss: 0.0725
# Epoch [1/5], Step [571/1912], Loss: 0.2239
# Epoch [1/5], Step [572/1912], Loss: 0.0123
# Epoch [1/5], Step [573/1912], Loss: 0.0141
# Epoch [1/5], Step [574/1912], Loss: 0.0119
# Epoch [1/5], Step [575/1912], Loss: 0.0121
# Epoch [1/5], Step [576/1912], Loss: 0.0136
# Epoch [1/5], Step [577/1912], Loss: 0.0114
# Epoch [1/5], Step [578/1912], Loss: 0.0171
# Epoch [1/5], Step [579/1912], Loss: 0.0131
# Epoch [1/5], Step [580/1912], Loss: 0.0136
# Epoch [1/5], Step [581/1912], Loss: 0.0414
# Epoch [1/5], Step [582/1912], Loss: 0.0128
# Epoch [1/5], Step [583/1912], Loss: 0.0144
# Epoch [1/5], Step [584/1912], Loss: 0.0115
# Epoch [1/5], Step [585/1912], Loss: 2.5873
# Epoch [1/5], Step [586/1912], Loss: 0.0279
# Epoch [1/5], Step [587/1912], Loss: 0.0168
# Epoch [1/5], Step [588/1912], Loss: 2.9883
# Epoch [1/5], Step [589/1912], Loss: 2.7948
# Epoch [1/5], Step [590/1912], Loss: 0.0307
# Epoch [1/5], Step [591/1912], Loss: 0.0582
# Epoch [1/5], Step [592/1912], Loss: 0.0251
# Epoch [1/5], Step [593/1912], Loss: 1.1218
# Epoch [1/5], Step [594/1912], Loss: 0.0379
# Epoch [1/5], Step [595/1912], Loss: 0.0483
# Epoch [1/5], Step [596/1912], Loss: 0.0587
# Epoch [1/5], Step [597/1912], Loss: 0.1002
# Epoch [1/5], Step [598/1912], Loss: 0.0961
# Epoch [1/5], Step [599/1912], Loss: 0.1920
# Epoch [1/5], Step [600/1912], Loss: 0.6402
# Epoch [1/5], Step [601/1912], Loss: 0.2103
# Epoch [1/5], Step [602/1912], Loss: 0.1504
# Epoch [1/5], Step [603/1912], Loss: 1.8035
# Epoch [1/5], Step [604/1912], Loss: 0.4077
# Epoch [1/5], Step [605/1912], Loss: 0.0273
# Epoch [1/5], Step [606/1912], Loss: 0.2658
# Epoch [1/5], Step [607/1912], Loss: 0.2491
# Epoch [1/5], Step [608/1912], Loss: 0.0174
# Epoch [1/5], Step [609/1912], Loss: 0.2979
# Epoch [1/5], Step [610/1912], Loss: 0.2084
# Epoch [1/5], Step [611/1912], Loss: 0.2840
# Epoch [1/5], Step [612/1912], Loss: 0.2115
# Epoch [1/5], Step [613/1912], Loss: 0.0205
# Epoch [1/5], Step [614/1912], Loss: 0.0211
# Epoch [1/5], Step [615/1912], Loss: 0.0244
# Epoch [1/5], Step [616/1912], Loss: 0.1610
# Epoch [1/5], Step [617/1912], Loss: 0.1692
# Epoch [1/5], Step [618/1912], Loss: 0.1233
# Epoch [1/5], Step [619/1912], Loss: 0.0182
# Epoch [1/5], Step [620/1912], Loss: 0.1932
# Epoch [1/5], Step [621/1912], Loss: 0.1158
# Epoch [1/5], Step [622/1912], Loss: 0.0181
# Epoch [1/5], Step [623/1912], Loss: 0.0183
# Epoch [1/5], Step [624/1912], Loss: 0.0151
# Epoch [1/5], Step [625/1912], Loss: 1.0370
# Epoch [1/5], Step [626/1912], Loss: 1.2429
# Epoch [1/5], Step [627/1912], Loss: 0.1884
# Epoch [1/5], Step [628/1912], Loss: 0.0157
# Epoch [1/5], Step [629/1912], Loss: 0.1572
# Epoch [1/5], Step [630/1912], Loss: 0.1088
# Epoch [1/5], Step [631/1912], Loss: 0.1475
# Epoch [1/5], Step [632/1912], Loss: 0.4480
# Epoch [1/5], Step [633/1912], Loss: 0.1081
# Epoch [1/5], Step [634/1912], Loss: 0.2888
# Epoch [1/5], Step [635/1912], Loss: 0.0613
# Epoch [1/5], Step [636/1912], Loss: 0.0135
# Epoch [1/5], Step [637/1912], Loss: 0.0221
# Epoch [1/5], Step [638/1912], Loss: 0.0115
# Epoch [1/5], Step [639/1912], Loss: 0.0113
# Epoch [1/5], Step [640/1912], Loss: 0.0118
# Epoch [1/5], Step [641/1912], Loss: 0.0203
# Epoch [1/5], Step [642/1912], Loss: 0.0124
# Epoch [1/5], Step [643/1912], Loss: 0.4774
# Epoch [1/5], Step [644/1912], Loss: 0.0097
# Epoch [1/5], Step [645/1912], Loss: 0.0108
# Epoch [1/5], Step [646/1912], Loss: 0.5149
# Epoch [1/5], Step [647/1912], Loss: 0.0153
# Epoch [1/5], Step [648/1912], Loss: 0.2925
# Epoch [1/5], Step [649/1912], Loss: 0.1678
# Epoch [1/5], Step [650/1912], Loss: 1.4130
# Epoch [1/5], Step [651/1912], Loss: 0.8070
# Epoch [1/5], Step [652/1912], Loss: 0.0376
# Epoch [1/5], Step [653/1912], Loss: 0.0366
# Epoch [1/5], Step [654/1912], Loss: 0.7574
# Epoch [1/5], Step [655/1912], Loss: 0.0094
# Epoch [1/5], Step [656/1912], Loss: 0.0207
# Epoch [1/5], Step [657/1912], Loss: 0.3832
# Epoch [1/5], Step [658/1912], Loss: 0.3708
# Epoch [1/5], Step [659/1912], Loss: 0.0284
# Epoch [1/5], Step [660/1912], Loss: 0.0093
# Epoch [1/5], Step [661/1912], Loss: 0.0085
# Epoch [1/5], Step [662/1912], Loss: 2.6282
# Epoch [1/5], Step [663/1912], Loss: 0.2505
# Epoch [1/5], Step [664/1912], Loss: 0.0327
# Epoch [1/5], Step [665/1912], Loss: 0.3810
# Epoch [1/5], Step [666/1912], Loss: 0.0106
# Epoch [1/5], Step [667/1912], Loss: 0.8950
# Epoch [1/5], Step [668/1912], Loss: 0.0126
# Epoch [1/5], Step [669/1912], Loss: 0.0131
# Epoch [1/5], Step [670/1912], Loss: 0.3795
# Epoch [1/5], Step [671/1912], Loss: 0.1369
# Epoch [1/5], Step [672/1912], Loss: 0.0690
# Epoch [1/5], Step [673/1912], Loss: 0.0201
# Epoch [1/5], Step [674/1912], Loss: 0.0203
# Epoch [1/5], Step [675/1912], Loss: 0.0466
# Epoch [1/5], Step [676/1912], Loss: 0.2519
# Epoch [1/5], Step [677/1912], Loss: 0.0812
# Epoch [1/5], Step [678/1912], Loss: 0.0192
# Epoch [1/5], Step [679/1912], Loss: 0.0275
# Epoch [1/5], Step [680/1912], Loss: 0.0767
# Epoch [1/5], Step [681/1912], Loss: 0.0500
# Epoch [1/5], Step [682/1912], Loss: 0.1300
# Epoch [1/5], Step [683/1912], Loss: 0.2306
# Epoch [1/5], Step [684/1912], Loss: 0.1085
# Epoch [1/5], Step [685/1912], Loss: 0.0464
# Epoch [1/5], Step [686/1912], Loss: 0.0406
# Epoch [1/5], Step [687/1912], Loss: 0.0414
# Epoch [1/5], Step [688/1912], Loss: 0.0218
# Epoch [1/5], Step [689/1912], Loss: 0.0322
# Epoch [1/5], Step [690/1912], Loss: 0.0352
# Epoch [1/5], Step [691/1912], Loss: 0.0277
# Epoch [1/5], Step [692/1912], Loss: 0.0386
# Epoch [1/5], Step [693/1912], Loss: 0.0868
# Epoch [1/5], Step [694/1912], Loss: 0.0347
# Epoch [1/5], Step [695/1912], Loss: 0.0281
# Epoch [1/5], Step [696/1912], Loss: 0.0553
# Epoch [1/5], Step [697/1912], Loss: 0.0348
# Epoch [1/5], Step [698/1912], Loss: 0.0328
# Epoch [1/5], Step [699/1912], Loss: 0.0161
# Epoch [1/5], Step [700/1912], Loss: 0.0783
# Epoch [1/5], Step [701/1912], Loss: 0.0303
# Epoch [1/5], Step [702/1912], Loss: 0.0219
# Epoch [1/5], Step [703/1912], Loss: 0.0213
# Epoch [1/5], Step [704/1912], Loss: 0.0190
# Epoch [1/5], Step [705/1912], Loss: 0.0177
# Epoch [1/5], Step [706/1912], Loss: 0.0163
# Epoch [1/5], Step [707/1912], Loss: 0.0313
# Epoch [1/5], Step [708/1912], Loss: 0.0332
# Epoch [1/5], Step [709/1912], Loss: 0.0170
# Epoch [1/5], Step [710/1912], Loss: 0.0594
# Epoch [1/5], Step [711/1912], Loss: 0.2187
# Epoch [1/5], Step [712/1912], Loss: 0.0431
# Epoch [1/5], Step [713/1912], Loss: 0.0155
# Epoch [1/5], Step [714/1912], Loss: 0.0420
# Epoch [1/5], Step [715/1912], Loss: 0.0917
# Epoch [1/5], Step [716/1912], Loss: 0.0144
# Epoch [1/5], Step [717/1912], Loss: 0.0122
# Epoch [1/5], Step [718/1912], Loss: 2.1109
# Epoch [1/5], Step [719/1912], Loss: 0.0122
# Epoch [1/5], Step [720/1912], Loss: 0.0136
# Epoch [1/5], Step [721/1912], Loss: 0.0187
# Epoch [1/5], Step [722/1912], Loss: 0.0683
# Epoch [1/5], Step [723/1912], Loss: 0.0100
# Epoch [1/5], Step [724/1912], Loss: 0.0984
# Epoch [1/5], Step [725/1912], Loss: 0.0293
# Epoch [1/5], Step [726/1912], Loss: 0.2109
# Epoch [1/5], Step [727/1912], Loss: 0.0446
# Epoch [1/5], Step [728/1912], Loss: 1.3068
# Epoch [1/5], Step [729/1912], Loss: 0.0111
# Epoch [1/5], Step [730/1912], Loss: 0.0091
# Epoch [1/5], Step [731/1912], Loss: 0.0092
# Epoch [1/5], Step [732/1912], Loss: 0.0089
# Epoch [1/5], Step [733/1912], Loss: 3.4996
# Epoch [1/5], Step [734/1912], Loss: 0.5879
# Epoch [1/5], Step [735/1912], Loss: 0.0119
# Epoch [1/5], Step [736/1912], Loss: 0.4722
# Epoch [1/5], Step [737/1912], Loss: 0.4031
# Epoch [1/5], Step [738/1912], Loss: 0.0114
# Epoch [1/5], Step [739/1912], Loss: 0.7447
# Epoch [1/5], Step [740/1912], Loss: 0.0126
# Epoch [1/5], Step [741/1912], Loss: 0.0830
# Epoch [1/5], Step [742/1912], Loss: 0.0446
# Epoch [1/5], Step [743/1912], Loss: 0.0178
# Epoch [1/5], Step [744/1912], Loss: 0.0847
# Epoch [1/5], Step [745/1912], Loss: 0.0735
# Epoch [1/5], Step [746/1912], Loss: 0.0160
# Epoch [1/5], Step [747/1912], Loss: 0.1589
# Epoch [1/5], Step [748/1912], Loss: 0.0142
# Epoch [1/5], Step [749/1912], Loss: 0.0174
# Epoch [1/5], Step [750/1912], Loss: 0.0166
# Epoch [1/5], Step [751/1912], Loss: 0.0167
# Epoch [1/5], Step [752/1912], Loss: 0.0443
# Epoch [1/5], Step [753/1912], Loss: 0.0783
# Epoch [1/5], Step [754/1912], Loss: 0.0174
# Epoch [1/5], Step [755/1912], Loss: 0.1554
# Epoch [1/5], Step [756/1912], Loss: 0.1452
# Epoch [1/5], Step [757/1912], Loss: 0.1148
# Epoch [1/5], Step [758/1912], Loss: 0.0133
# Epoch [1/5], Step [759/1912], Loss: 0.1106
# Epoch [1/5], Step [760/1912], Loss: 0.0628
# Epoch [1/5], Step [761/1912], Loss: 0.0818
# Epoch [1/5], Step [762/1912], Loss: 0.0125
# Epoch [1/5], Step [763/1912], Loss: 0.0126
# Epoch [1/5], Step [764/1912], Loss: 1.5639
# Epoch [1/5], Step [765/1912], Loss: 0.2131
# Epoch [1/5], Step [766/1912], Loss: 0.1549
# Epoch [1/5], Step [767/1912], Loss: 0.0115
# Epoch [1/5], Step [768/1912], Loss: 0.0115
# Epoch [1/5], Step [769/1912], Loss: 0.0573
# Epoch [1/5], Step [770/1912], Loss: 0.0126
# Epoch [1/5], Step [771/1912], Loss: 2.7024
# Epoch [1/5], Step [772/1912], Loss: 0.0107
# Epoch [1/5], Step [773/1912], Loss: 0.0153
# Epoch [1/5], Step [774/1912], Loss: 0.0118
# Epoch [1/5], Step [775/1912], Loss: 0.0178
# Epoch [1/5], Step [776/1912], Loss: 0.0574
# Epoch [1/5], Step [777/1912], Loss: 0.0156
# Epoch [1/5], Step [778/1912], Loss: 0.0140
# Epoch [1/5], Step [779/1912], Loss: 0.0156
# Epoch [1/5], Step [780/1912], Loss: 0.0172
# Epoch [1/5], Step [781/1912], Loss: 0.0173
# Epoch [1/5], Step [782/1912], Loss: 0.0253
# Epoch [1/5], Step [783/1912], Loss: 0.0472
# Epoch [1/5], Step [784/1912], Loss: 0.0207
# Epoch [1/5], Step [785/1912], Loss: 0.0183
# Epoch [1/5], Step [786/1912], Loss: 0.0199
# Epoch [1/5], Step [787/1912], Loss: 0.1104
# Epoch [1/5], Step [788/1912], Loss: 0.0155
# Epoch [1/5], Step [789/1912], Loss: 0.0162
# Epoch [1/5], Step [790/1912], Loss: 0.0855
# Epoch [1/5], Step [791/1912], Loss: 0.1176
# Epoch [1/5], Step [792/1912], Loss: 0.0475
# Epoch [1/5], Step [793/1912], Loss: 0.1663
# Epoch [1/5], Step [794/1912], Loss: 0.0169
# Epoch [1/5], Step [795/1912], Loss: 0.0160
# Epoch [1/5], Step [796/1912], Loss: 0.3898
# Epoch [1/5], Step [797/1912], Loss: 0.0146
# Epoch [1/5], Step [798/1912], Loss: 0.3492
# Epoch [1/5], Step [799/1912], Loss: 3.3006
# Epoch [1/5], Step [800/1912], Loss: 0.0395
# Epoch [1/5], Step [801/1912], Loss: 0.0200
# Epoch [1/5], Step [802/1912], Loss: 0.0211
# Epoch [1/5], Step [803/1912], Loss: 0.0253
# Epoch [1/5], Step [804/1912], Loss: 0.0269
# Epoch [1/5], Step [805/1912], Loss: 0.2801
# Epoch [1/5], Step [806/1912], Loss: 0.0576
# Epoch [1/5], Step [807/1912], Loss: 0.0690
# Epoch [1/5], Step [808/1912], Loss: 0.0666
# Epoch [1/5], Step [809/1912], Loss: 0.0538
# Epoch [1/5], Step [810/1912], Loss: 0.4944
# Epoch [1/5], Step [811/1912], Loss: 0.0685
# Epoch [1/5], Step [812/1912], Loss: 0.3285
# Epoch [1/5], Step [813/1912], Loss: 0.0364
# Epoch [1/5], Step [814/1912], Loss: 0.0442
# Epoch [1/5], Step [815/1912], Loss: 0.0604
# Epoch [1/5], Step [816/1912], Loss: 0.1198
# Epoch [1/5], Step [817/1912], Loss: 0.0358
# Epoch [1/5], Step [818/1912], Loss: 0.0430
# Epoch [1/5], Step [819/1912], Loss: 0.0317
# Epoch [1/5], Step [820/1912], Loss: 1.2586
# Epoch [1/5], Step [821/1912], Loss: 0.0845
# Epoch [1/5], Step [822/1912], Loss: 0.0149
# Epoch [1/5], Step [823/1912], Loss: 0.1229
# Epoch [1/5], Step [824/1912], Loss: 0.0160
# Epoch [1/5], Step [825/1912], Loss: 0.0148
# Epoch [1/5], Step [826/1912], Loss: 0.0191
# Epoch [1/5], Step [827/1912], Loss: 0.2845
# Epoch [1/5], Step [828/1912], Loss: 0.1007
# Epoch [1/5], Step [829/1912], Loss: 0.0150
# Epoch [1/5], Step [830/1912], Loss: 0.0198
# Epoch [1/5], Step [831/1912], Loss: 1.2949
# Epoch [1/5], Step [832/1912], Loss: 2.4905
# Epoch [1/5], Step [833/1912], Loss: 0.0209
# Epoch [1/5], Step [834/1912], Loss: 0.0113
# Epoch [1/5], Step [835/1912], Loss: 0.2469
# Epoch [1/5], Step [836/1912], Loss: 0.0115
# Epoch [1/5], Step [837/1912], Loss: 0.7550
# Epoch [1/5], Step [838/1912], Loss: 0.5100
# Epoch [1/5], Step [839/1912], Loss: 3.3259
# Epoch [1/5], Step [840/1912], Loss: 0.0132
# Epoch [1/5], Step [841/1912], Loss: 0.5833
# Epoch [1/5], Step [842/1912], Loss: 0.0690
# Epoch [1/5], Step [843/1912], Loss: 0.0114
# Epoch [1/5], Step [844/1912], Loss: 0.1606
# Epoch [1/5], Step [845/1912], Loss: 0.0127
# Epoch [1/5], Step [846/1912], Loss: 0.6637
# Epoch [1/5], Step [847/1912], Loss: 0.0158
# Epoch [1/5], Step [848/1912], Loss: 0.0137
# Epoch [1/5], Step [849/1912], Loss: 0.3593
# Epoch [1/5], Step [850/1912], Loss: 0.0150
# Epoch [1/5], Step [851/1912], Loss: 0.0177
# Epoch [1/5], Step [852/1912], Loss: 0.1079
# Epoch [1/5], Step [853/1912], Loss: 0.2048
# Epoch [1/5], Step [854/1912], Loss: 0.0168
# Epoch [1/5], Step [855/1912], Loss: 0.2296
# Epoch [1/5], Step [856/1912], Loss: 0.0141
# Epoch [1/5], Step [857/1912], Loss: 0.0949
# Epoch [1/5], Step [858/1912], Loss: 2.7246
# Epoch [1/5], Step [859/1912], Loss: 0.0214
# Epoch [1/5], Step [860/1912], Loss: 0.0190
# Epoch [1/5], Step [861/1912], Loss: 0.0186
# Epoch [1/5], Step [862/1912], Loss: 0.0210
# Epoch [1/5], Step [863/1912], Loss: 0.0279
# Epoch [1/5], Step [864/1912], Loss: 0.0212
# Epoch [1/5], Step [865/1912], Loss: 0.0236
# Epoch [1/5], Step [866/1912], Loss: 1.9336
# Epoch [1/5], Step [867/1912], Loss: 0.1885
# Epoch [1/5], Step [868/1912], Loss: 0.0239
# Epoch [1/5], Step [869/1912], Loss: 0.0935
# Epoch [1/5], Step [870/1912], Loss: 0.0519
# Epoch [1/5], Step [871/1912], Loss: 2.0185
# Epoch [1/5], Step [872/1912], Loss: 0.0542
# Epoch [1/5], Step [873/1912], Loss: 0.0346
# Epoch [1/5], Step [874/1912], Loss: 0.0454
# Epoch [1/5], Step [875/1912], Loss: 0.1000
# Epoch [1/5], Step [876/1912], Loss: 0.1374
# Epoch [1/5], Step [877/1912], Loss: 0.2774
# Epoch [1/5], Step [878/1912], Loss: 0.1591
# Epoch [1/5], Step [879/1912], Loss: 0.2855
# Epoch [1/5], Step [880/1912], Loss: 0.0321
# Epoch [1/5], Step [881/1912], Loss: 0.0585
# Epoch [1/5], Step [882/1912], Loss: 0.1269
# Epoch [1/5], Step [883/1912], Loss: 0.0343
# Epoch [1/5], Step [884/1912], Loss: 0.0609
# Epoch [1/5], Step [885/1912], Loss: 0.0387
# Epoch [1/5], Step [886/1912], Loss: 0.1148
# Epoch [1/5], Step [887/1912], Loss: 0.0422
# Epoch [1/5], Step [888/1912], Loss: 0.0369
# Epoch [1/5], Step [889/1912], Loss: 0.0452
# Epoch [1/5], Step [890/1912], Loss: 0.0497
# Epoch [1/5], Step [891/1912], Loss: 0.0756
# Epoch [1/5], Step [892/1912], Loss: 0.0462
# Epoch [1/5], Step [893/1912], Loss: 0.0387
# Epoch [1/5], Step [894/1912], Loss: 0.3937
# Epoch [1/5], Step [895/1912], Loss: 0.0397
# Epoch [1/5], Step [896/1912], Loss: 0.0369
# Epoch [1/5], Step [897/1912], Loss: 0.7315
# Epoch [1/5], Step [898/1912], Loss: 0.7194
# Epoch [1/5], Step [899/1912], Loss: 0.0273
# Epoch [1/5], Step [900/1912], Loss: 0.0258
# Epoch [1/5], Step [901/1912], Loss: 0.1094
# Epoch [1/5], Step [902/1912], Loss: 0.0221
# Epoch [1/5], Step [903/1912], Loss: 0.0205
# Epoch [1/5], Step [904/1912], Loss: 2.2030
# Epoch [1/5], Step [905/1912], Loss: 0.0262
# Epoch [1/5], Step [906/1912], Loss: 0.0547
# Epoch [1/5], Step [907/1912], Loss: 1.7139
# Epoch [1/5], Step [908/1912], Loss: 0.1386
# Epoch [1/5], Step [909/1912], Loss: 0.0249
# Epoch [1/5], Step [910/1912], Loss: 0.0215
# Epoch [1/5], Step [911/1912], Loss: 0.0239
# Epoch [1/5], Step [912/1912], Loss: 0.0232
# Epoch [1/5], Step [913/1912], Loss: 0.0288
# Epoch [1/5], Step [914/1912], Loss: 0.3470
# Epoch [1/5], Step [915/1912], Loss: 0.0840
# Epoch [1/5], Step [916/1912], Loss: 0.0264
# Epoch [1/5], Step [917/1912], Loss: 0.0255
# Epoch [1/5], Step [918/1912], Loss: 0.3010
# Epoch [1/5], Step [919/1912], Loss: 0.0245
# Epoch [1/5], Step [920/1912], Loss: 0.0379
# Epoch [1/5], Step [921/1912], Loss: 0.0450
# Epoch [1/5], Step [922/1912], Loss: 0.0266
# Epoch [1/5], Step [923/1912], Loss: 0.0235
# Epoch [1/5], Step [924/1912], Loss: 0.2408
# Epoch [1/5], Step [925/1912], Loss: 0.0209
# Epoch [1/5], Step [926/1912], Loss: 0.2703
# Epoch [1/5], Step [927/1912], Loss: 0.0201
# Epoch [1/5], Step [928/1912], Loss: 0.0557
# Epoch [1/5], Step [929/1912], Loss: 0.0240
# Epoch [1/5], Step [930/1912], Loss: 0.0206
# Epoch [1/5], Step [931/1912], Loss: 0.0219
# Epoch [1/5], Step [932/1912], Loss: 0.0993
# Epoch [1/5], Step [933/1912], Loss: 0.6595
# Epoch [1/5], Step [934/1912], Loss: 0.0159
# Epoch [1/5], Step [935/1912], Loss: 1.7346
# Epoch [1/5], Step [936/1912], Loss: 0.0461
# Epoch [1/5], Step [937/1912], Loss: 0.1514
# Epoch [1/5], Step [938/1912], Loss: 0.0630
# Epoch [1/5], Step [939/1912], Loss: 0.0484
# Epoch [1/5], Step [940/1912], Loss: 0.0820
# Epoch [1/5], Step [941/1912], Loss: 0.0859
# Epoch [1/5], Step [942/1912], Loss: 0.0296
# Epoch [1/5], Step [943/1912], Loss: 0.0605
# Epoch [1/5], Step [944/1912], Loss: 0.0330
# Epoch [1/5], Step [945/1912], Loss: 0.0305
# Epoch [1/5], Step [946/1912], Loss: 0.0210
# Epoch [1/5], Step [947/1912], Loss: 0.0442
# Epoch [1/5], Step [948/1912], Loss: 0.0226
# Epoch [1/5], Step [949/1912], Loss: 0.0421
# Epoch [1/5], Step [950/1912], Loss: 0.0234
# Epoch [1/5], Step [951/1912], Loss: 0.0314
# Epoch [1/5], Step [952/1912], Loss: 0.0230
# Epoch [1/5], Step [953/1912], Loss: 0.3491
# Epoch [1/5], Step [954/1912], Loss: 0.0231
# Epoch [1/5], Step [955/1912], Loss: 0.1122
# Epoch [1/5], Step [956/1912], Loss: 0.0247
# Epoch [1/5], Step [957/1912], Loss: 0.0255
# Epoch [1/5], Step [958/1912], Loss: 0.0436
# Epoch [1/5], Step [959/1912], Loss: 0.0240
# Epoch [1/5], Step [960/1912], Loss: 0.0187
# Epoch [1/5], Step [961/1912], Loss: 0.0258
# Epoch [1/5], Step [962/1912], Loss: 0.1696
# Epoch [1/5], Step [963/1912], Loss: 0.1556
# Epoch [1/5], Step [964/1912], Loss: 0.0192
# Epoch [1/5], Step [965/1912], Loss: 0.0154
# Epoch [1/5], Step [966/1912], Loss: 0.0216
# Epoch [1/5], Step [967/1912], Loss: 0.1962
# Epoch [1/5], Step [968/1912], Loss: 2.9578
# Epoch [1/5], Step [969/1912], Loss: 0.0157
# Epoch [1/5], Step [970/1912], Loss: 0.0161
# Epoch [1/5], Step [971/1912], Loss: 0.0414
# Epoch [1/5], Step [972/1912], Loss: 2.5964
# Epoch [1/5], Step [973/1912], Loss: 0.0343
# Epoch [1/5], Step [974/1912], Loss: 0.0141
# Epoch [1/5], Step [975/1912], Loss: 0.0129
# Epoch [1/5], Step [976/1912], Loss: 2.1425
# Epoch [1/5], Step [977/1912], Loss: 0.3213
# Epoch [1/5], Step [978/1912], Loss: 0.0115
# Epoch [1/5], Step [979/1912], Loss: 0.1299
# Epoch [1/5], Step [980/1912], Loss: 0.1241
# Epoch [1/5], Step [981/1912], Loss: 0.1518
# Epoch [1/5], Step [982/1912], Loss: 0.0123
# Epoch [1/5], Step [983/1912], Loss: 0.0131
# Epoch [1/5], Step [984/1912], Loss: 0.0132
# Epoch [1/5], Step [985/1912], Loss: 0.0292
# Epoch [1/5], Step [986/1912], Loss: 0.0140
# Epoch [1/5], Step [987/1912], Loss: 0.1583
# Epoch [1/5], Step [988/1912], Loss: 0.1579
# Epoch [1/5], Step [989/1912], Loss: 0.0143
# Epoch [1/5], Step [990/1912], Loss: 0.0141
# Epoch [1/5], Step [991/1912], Loss: 0.3940
# Epoch [1/5], Step [992/1912], Loss: 0.0704
# Epoch [1/5], Step [993/1912], Loss: 0.4541
# Epoch [1/5], Step [994/1912], Loss: 0.0113
# Epoch [1/5], Step [995/1912], Loss: 0.1760
# Epoch [1/5], Step [996/1912], Loss: 0.9548
# Epoch [1/5], Step [997/1912], Loss: 0.0131
# Epoch [1/5], Step [998/1912], Loss: 0.0141
# Epoch [1/5], Step [999/1912], Loss: 0.2191
# Epoch [1/5], Step [1000/1912], Loss: 0.0144
# Epoch [1/5], Step [1001/1912], Loss: 0.0259
# Epoch [1/5], Step [1002/1912], Loss: 0.0145
# Epoch [1/5], Step [1003/1912], Loss: 1.2729
# Epoch [1/5], Step [1004/1912], Loss: 0.0139
# Epoch [1/5], Step [1005/1912], Loss: 0.0534
# Epoch [1/5], Step [1006/1912], Loss: 0.0189
# Epoch [1/5], Step [1007/1912], Loss: 0.0347
# Epoch [1/5], Step [1008/1912], Loss: 0.1951
# Epoch [1/5], Step [1009/1912], Loss: 0.1519
# Epoch [1/5], Step [1010/1912], Loss: 0.0259
# Epoch [1/5], Step [1011/1912], Loss: 0.0118
# Epoch [1/5], Step [1012/1912], Loss: 0.0107
# Epoch [1/5], Step [1013/1912], Loss: 0.0105
# Epoch [1/5], Step [1014/1912], Loss: 0.1991
# Epoch [1/5], Step [1015/1912], Loss: 0.0180
# Epoch [1/5], Step [1016/1912], Loss: 0.0129
# Epoch [1/5], Step [1017/1912], Loss: 1.6071
# Epoch [1/5], Step [1018/1912], Loss: 0.0112
# Epoch [1/5], Step [1019/1912], Loss: 0.7754
# Epoch [1/5], Step [1020/1912], Loss: 0.0127
# Epoch [1/5], Step [1021/1912], Loss: 0.0118
# Epoch [1/5], Step [1022/1912], Loss: 0.0153
# Epoch [1/5], Step [1023/1912], Loss: 0.2899
# Epoch [1/5], Step [1024/1912], Loss: 0.0122
# Epoch [1/5], Step [1025/1912], Loss: 0.1453
# Epoch [1/5], Step [1026/1912], Loss: 0.1658
# Epoch [1/5], Step [1027/1912], Loss: 0.0118
# Epoch [1/5], Step [1028/1912], Loss: 0.1961
# Epoch [1/5], Step [1029/1912], Loss: 0.0951
# Epoch [1/5], Step [1030/1912], Loss: 0.2781
# Epoch [1/5], Step [1031/1912], Loss: 0.0110
# Epoch [1/5], Step [1032/1912], Loss: 2.4002
# Epoch [1/5], Step [1033/1912], Loss: 0.0125
# Epoch [1/5], Step [1034/1912], Loss: 0.3775
# Epoch [1/5], Step [1035/1912], Loss: 1.5878
# Epoch [1/5], Step [1036/1912], Loss: 0.0207
# Epoch [1/5], Step [1037/1912], Loss: 0.0156
# Epoch [1/5], Step [1038/1912], Loss: 0.0904
# Epoch [1/5], Step [1039/1912], Loss: 0.0697
# Epoch [1/5], Step [1040/1912], Loss: 0.0160
# Epoch [1/5], Step [1041/1912], Loss: 0.0180
# Epoch [1/5], Step [1042/1912], Loss: 0.0237
# Epoch [1/5], Step [1043/1912], Loss: 0.0195
# Epoch [1/5], Step [1044/1912], Loss: 0.0548
# Epoch [1/5], Step [1045/1912], Loss: 0.3936
# Epoch [1/5], Step [1046/1912], Loss: 0.0254
# Epoch [1/5], Step [1047/1912], Loss: 0.3467
# Epoch [1/5], Step [1048/1912], Loss: 0.0465
# Epoch [1/5], Step [1049/1912], Loss: 0.0654
# Epoch [1/5], Step [1050/1912], Loss: 0.0365
# Epoch [1/5], Step [1051/1912], Loss: 0.0237
# Epoch [1/5], Step [1052/1912], Loss: 0.0176
# Epoch [1/5], Step [1053/1912], Loss: 0.0226
# Epoch [1/5], Step [1054/1912], Loss: 0.2441
# Epoch [1/5], Step [1055/1912], Loss: 0.0158
# Epoch [1/5], Step [1056/1912], Loss: 0.0848
# Epoch [1/5], Step [1057/1912], Loss: 0.0696
# Epoch [1/5], Step [1058/1912], Loss: 0.0480
# Epoch [1/5], Step [1059/1912], Loss: 0.0612
# Epoch [1/5], Step [1060/1912], Loss: 0.0219
# Epoch [1/5], Step [1061/1912], Loss: 0.0145
# Epoch [1/5], Step [1062/1912], Loss: 0.0455
# Epoch [1/5], Step [1063/1912], Loss: 0.0640
# Epoch [1/5], Step [1064/1912], Loss: 0.0350
# Epoch [1/5], Step [1065/1912], Loss: 0.0451
# Epoch [1/5], Step [1066/1912], Loss: 0.0149
# Epoch [1/5], Step [1067/1912], Loss: 0.0145
# Epoch [1/5], Step [1068/1912], Loss: 0.0164
# Epoch [1/5], Step [1069/1912], Loss: 0.0691
# Epoch [1/5], Step [1070/1912], Loss: 0.0138
# Epoch [1/5], Step [1071/1912], Loss: 0.0255
# Epoch [1/5], Step [1072/1912], Loss: 2.9528
# Epoch [1/5], Step [1073/1912], Loss: 0.0107
# Epoch [1/5], Step [1074/1912], Loss: 0.0250
# Epoch [1/5], Step [1075/1912], Loss: 0.0865
# Epoch [1/5], Step [1076/1912], Loss: 0.0099
# Epoch [1/5], Step [1077/1912], Loss: 0.0103
# Epoch [1/5], Step [1078/1912], Loss: 0.0092
# Epoch [1/5], Step [1079/1912], Loss: 0.0110
# Epoch [1/5], Step [1080/1912], Loss: 0.0110
# Epoch [1/5], Step [1081/1912], Loss: 0.1139
# Epoch [1/5], Step [1082/1912], Loss: 0.2101
# Epoch [1/5], Step [1083/1912], Loss: 0.0278
# Epoch [1/5], Step [1084/1912], Loss: 0.0519
# Epoch [1/5], Step [1085/1912], Loss: 0.0203
# Epoch [1/5], Step [1086/1912], Loss: 0.0086
# Epoch [1/5], Step [1087/1912], Loss: 0.0104
# Epoch [1/5], Step [1088/1912], Loss: 0.0127
# Epoch [1/5], Step [1089/1912], Loss: 0.0925
# Epoch [1/5], Step [1090/1912], Loss: 0.0086
# Epoch [1/5], Step [1091/1912], Loss: 0.0092
# Epoch [1/5], Step [1092/1912], Loss: 0.0182
# Epoch [1/5], Step [1093/1912], Loss: 0.1044
# Epoch [1/5], Step [1094/1912], Loss: 0.2394
# Epoch [1/5], Step [1095/1912], Loss: 1.3477
# Epoch [1/5], Step [1096/1912], Loss: 0.0523
# Epoch [1/5], Step [1097/1912], Loss: 0.0093
# Epoch [1/5], Step [1098/1912], Loss: 0.1295
# Epoch [1/5], Step [1099/1912], Loss: 0.4662
# Epoch [1/5], Step [1100/1912], Loss: 0.0074
# Epoch [1/5], Step [1101/1912], Loss: 0.0368
# Epoch [1/5], Step [1102/1912], Loss: 0.0067
# Epoch [1/5], Step [1103/1912], Loss: 0.0086
# Epoch [1/5], Step [1104/1912], Loss: 0.0847
# Epoch [1/5], Step [1105/1912], Loss: 0.0082
# Epoch [1/5], Step [1106/1912], Loss: 0.5521
# Epoch [1/5], Step [1107/1912], Loss: 0.0079
# Epoch [1/5], Step [1108/1912], Loss: 0.0066
# Epoch [1/5], Step [1109/1912], Loss: 0.3398
# Epoch [1/5], Step [1110/1912], Loss: 0.0304
# Epoch [1/5], Step [1111/1912], Loss: 0.0072
# Epoch [1/5], Step [1112/1912], Loss: 0.0546
# Epoch [1/5], Step [1113/1912], Loss: 0.0840
# Epoch [1/5], Step [1114/1912], Loss: 0.0907
# Epoch [1/5], Step [1115/1912], Loss: 0.0082
# Epoch [1/5], Step [1116/1912], Loss: 0.0075
# ...
# Epoch [5/5], Step [1552/1912], Loss: 0.0278
# Epoch [5/5], Step [1553/1912], Loss: 0.0017
# Epoch [5/5], Step [1554/1912], Loss: 0.0021
# Epoch [5/5], Step [1555/1912], Loss: 0.0021
# Epoch [5/5], Step [1556/1912], Loss: 0.0020
# Epoch [5/5], Step [1557/1912], Loss: 0.0345
# Epoch [5/5], Step [1558/1912], Loss: 0.0020
# Epoch [5/5], Step [1559/1912], Loss: 0.0948
# Epoch [5/5], Step [1560/1912], Loss: 0.0053
# Epoch [5/5], Step [1561/1912], Loss: 0.1512
# Epoch [5/5], Step [1562/1912], Loss: 0.2349
# Epoch [5/5], Step [1563/1912], Loss: 0.0017
# Epoch [5/5], Step [1564/1912], Loss: 0.0239
# Epoch [5/5], Step [1565/1912], Loss: 0.0016
# Epoch [5/5], Step [1566/1912], Loss: 0.0014
# Epoch [5/5], Step [1567/1912], Loss: 0.1004
# Epoch [5/5], Step [1568/1912], Loss: 0.0020
# Epoch [5/5], Step [1569/1912], Loss: 0.0021
# Epoch [5/5], Step [1570/1912], Loss: 1.6483
# Epoch [5/5], Step [1571/1912], Loss: 0.0020
# Epoch [5/5], Step [1572/1912], Loss: 0.0397
# Epoch [5/5], Step [1573/1912], Loss: 0.0017
# Epoch [5/5], Step [1574/1912], Loss: 0.0018
# Epoch [5/5], Step [1575/1912], Loss: 0.0036
# Epoch [5/5], Step [1576/1912], Loss: 0.0414
# Epoch [5/5], Step [1577/1912], Loss: 0.2343
# Epoch [5/5], Step [1578/1912], Loss: 0.0297
# Epoch [5/5], Step [1579/1912], Loss: 0.0017
# Epoch [5/5], Step [1580/1912], Loss: 0.3598
# Epoch [5/5], Step [1581/1912], Loss: 0.0018
# Epoch [5/5], Step [1582/1912], Loss: 0.0522
# Epoch [5/5], Step [1583/1912], Loss: 0.0021
# Epoch [5/5], Step [1584/1912], Loss: 0.0033
# Epoch [5/5], Step [1585/1912], Loss: 0.0014
# Epoch [5/5], Step [1586/1912], Loss: 0.0680
# Epoch [5/5], Step [1587/1912], Loss: 0.0016
# Epoch [5/5], Step [1588/1912], Loss: 0.0222
# Epoch [5/5], Step [1589/1912], Loss: 0.0325
# Epoch [5/5], Step [1590/1912], Loss: 0.0242
# Epoch [5/5], Step [1591/1912], Loss: 0.0541
# Epoch [5/5], Step [1592/1912], Loss: 0.0019
# Epoch [5/5], Step [1593/1912], Loss: 0.0065
# Epoch [5/5], Step [1594/1912], Loss: 0.0556
# Epoch [5/5], Step [1595/1912], Loss: 0.0018
# Epoch [5/5], Step [1596/1912], Loss: 0.3447
# Epoch [5/5], Step [1597/1912], Loss: 0.0955
# Epoch [5/5], Step [1598/1912], Loss: 0.0013
# Epoch [5/5], Step [1599/1912], Loss: 0.1643
# Epoch [5/5], Step [1600/1912], Loss: 0.0016
# Epoch [5/5], Step [1601/1912], Loss: 0.0015
# Epoch [5/5], Step [1602/1912], Loss: 0.0016
# Epoch [5/5], Step [1603/1912], Loss: 0.0292
# Epoch [5/5], Step [1604/1912], Loss: 0.0054
# Epoch [5/5], Step [1605/1912], Loss: 0.0021
# Epoch [5/5], Step [1606/1912], Loss: 0.0737
# Epoch [5/5], Step [1607/1912], Loss: 0.0014
# Epoch [5/5], Step [1608/1912], Loss: 0.0194
# Epoch [5/5], Step [1609/1912], Loss: 0.0525
# Epoch [5/5], Step [1610/1912], Loss: 0.0017
# Epoch [5/5], Step [1611/1912], Loss: 0.0290
# Epoch [5/5], Step [1612/1912], Loss: 0.0024
# Epoch [5/5], Step [1613/1912], Loss: 0.0012
# Epoch [5/5], Step [1614/1912], Loss: 1.7778
# Epoch [5/5], Step [1615/1912], Loss: 0.0595
# Epoch [5/5], Step [1616/1912], Loss: 0.0014
# Epoch [5/5], Step [1617/1912], Loss: 0.0183
# Epoch [5/5], Step [1618/1912], Loss: 0.0051
# Epoch [5/5], Step [1619/1912], Loss: 0.0014
# Epoch [5/5], Step [1620/1912], Loss: 0.0020
# Epoch [5/5], Step [1621/1912], Loss: 0.0014
# Epoch [5/5], Step [1622/1912], Loss: 0.0017
# Epoch [5/5], Step [1623/1912], Loss: 0.0016
# Epoch [5/5], Step [1624/1912], Loss: 0.0017
# Epoch [5/5], Step [1625/1912], Loss: 0.0095
# Epoch [5/5], Step [1626/1912], Loss: 0.0018
# Epoch [5/5], Step [1627/1912], Loss: 2.5250
# Epoch [5/5], Step [1628/1912], Loss: 0.0019
# Epoch [5/5], Step [1629/1912], Loss: 0.0755
# Epoch [5/5], Step [1630/1912], Loss: 0.0025
# Epoch [5/5], Step [1631/1912], Loss: 0.1524
# Epoch [5/5], Step [1632/1912], Loss: 0.4182
# Epoch [5/5], Step [1633/1912], Loss: 0.0029
# Epoch [5/5], Step [1634/1912], Loss: 0.0891
# Epoch [5/5], Step [1635/1912], Loss: 0.0197
# Epoch [5/5], Step [1636/1912], Loss: 0.0018
# Epoch [5/5], Step [1637/1912], Loss: 0.5342
# Epoch [5/5], Step [1638/1912], Loss: 0.0549
# Epoch [5/5], Step [1639/1912], Loss: 0.1488
# Epoch [5/5], Step [1640/1912], Loss: 0.2798
# Epoch [5/5], Step [1641/1912], Loss: 0.0632
# Epoch [5/5], Step [1642/1912], Loss: 0.0016
# Epoch [5/5], Step [1643/1912], Loss: 0.0445
# Epoch [5/5], Step [1644/1912], Loss: 0.0014
# Epoch [5/5], Step [1645/1912], Loss: 0.0331
# Epoch [5/5], Step [1646/1912], Loss: 0.0014
# Epoch [5/5], Step [1647/1912], Loss: 0.0014
# Epoch [5/5], Step [1648/1912], Loss: 0.0014
# Epoch [5/5], Step [1649/1912], Loss: 0.0013
# Epoch [5/5], Step [1650/1912], Loss: 2.6784
# Epoch [5/5], Step [1651/1912], Loss: 0.0011
# Epoch [5/5], Step [1652/1912], Loss: 0.0039
# Epoch [5/5], Step [1653/1912], Loss: 0.0038
# Epoch [5/5], Step [1654/1912], Loss: 0.0014
# Epoch [5/5], Step [1655/1912], Loss: 0.0775
# Epoch [5/5], Step [1656/1912], Loss: 0.0862
# Epoch [5/5], Step [1657/1912], Loss: 0.1214
# Epoch [5/5], Step [1658/1912], Loss: 0.0217
# Epoch [5/5], Step [1659/1912], Loss: 0.0015
# Epoch [5/5], Step [1660/1912], Loss: 0.0016
# Epoch [5/5], Step [1661/1912], Loss: 0.0016
# Epoch [5/5], Step [1662/1912], Loss: 0.3330
# Epoch [5/5], Step [1663/1912], Loss: 0.0055
# Epoch [5/5], Step [1664/1912], Loss: 0.0944
# Epoch [5/5], Step [1665/1912], Loss: 0.0599
# Epoch [5/5], Step [1666/1912], Loss: 0.0748
# Epoch [5/5], Step [1667/1912], Loss: 1.3219
# Epoch [5/5], Step [1668/1912], Loss: 0.0016
# Epoch [5/5], Step [1669/1912], Loss: 0.1602
# Epoch [5/5], Step [1670/1912], Loss: 0.1631
# Epoch [5/5], Step [1671/1912], Loss: 0.0018
# Epoch [5/5], Step [1672/1912], Loss: 0.1138
# Epoch [5/5], Step [1673/1912], Loss: 0.0019
# Epoch [5/5], Step [1674/1912], Loss: 0.0017
# Epoch [5/5], Step [1675/1912], Loss: 0.0148
# Epoch [5/5], Step [1676/1912], Loss: 0.0020
# Epoch [5/5], Step [1677/1912], Loss: 0.0019
# Epoch [5/5], Step [1678/1912], Loss: 0.1536
# Epoch [5/5], Step [1679/1912], Loss: 0.0024
# Epoch [5/5], Step [1680/1912], Loss: 0.0019
# Epoch [5/5], Step [1681/1912], Loss: 0.0185
# Epoch [5/5], Step [1682/1912], Loss: 0.0458
# Epoch [5/5], Step [1683/1912], Loss: 1.0595
# Epoch [5/5], Step [1684/1912], Loss: 0.0026
# Epoch [5/5], Step [1685/1912], Loss: 0.0132
# Epoch [5/5], Step [1686/1912], Loss: 0.0017
# Epoch [5/5], Step [1687/1912], Loss: 0.3464
# Epoch [5/5], Step [1688/1912], Loss: 0.0032
# Epoch [5/5], Step [1689/1912], Loss: 0.0018
# Epoch [5/5], Step [1690/1912], Loss: 0.0026
# Epoch [5/5], Step [1691/1912], Loss: 0.0191
# Epoch [5/5], Step [1692/1912], Loss: 0.0204
# Epoch [5/5], Step [1693/1912], Loss: 0.0028
# Epoch [5/5], Step [1694/1912], Loss: 0.0018
# Epoch [5/5], Step [1695/1912], Loss: 0.0043
# Epoch [5/5], Step [1696/1912], Loss: 0.0018
# Epoch [5/5], Step [1697/1912], Loss: 0.5649
# Epoch [5/5], Step [1698/1912], Loss: 0.0223
# Epoch [5/5], Step [1699/1912], Loss: 0.6783
# Epoch [5/5], Step [1700/1912], Loss: 0.0027
# Epoch [5/5], Step [1701/1912], Loss: 0.0018
# Epoch [5/5], Step [1702/1912], Loss: 0.0121
# Epoch [5/5], Step [1703/1912], Loss: 0.0018
# Epoch [5/5], Step [1704/1912], Loss: 0.0610
# Epoch [5/5], Step [1705/1912], Loss: 0.0210
# Epoch [5/5], Step [1706/1912], Loss: 0.1012
# Epoch [5/5], Step [1707/1912], Loss: 0.0265
# Epoch [5/5], Step [1708/1912], Loss: 0.0017
# Epoch [5/5], Step [1709/1912], Loss: 0.0019
# Epoch [5/5], Step [1710/1912], Loss: 0.0029
# Epoch [5/5], Step [1711/1912], Loss: 0.0023
# Epoch [5/5], Step [1712/1912], Loss: 0.3252
# Epoch [5/5], Step [1713/1912], Loss: 0.0169
# Epoch [5/5], Step [1714/1912], Loss: 0.0017
# Epoch [5/5], Step [1715/1912], Loss: 0.0037
# Epoch [5/5], Step [1716/1912], Loss: 0.0019
# Epoch [5/5], Step [1717/1912], Loss: 0.0026
# Epoch [5/5], Step [1718/1912], Loss: 0.0018
# Epoch [5/5], Step [1719/1912], Loss: 0.0018
# Epoch [5/5], Step [1720/1912], Loss: 0.0166
# Epoch [5/5], Step [1721/1912], Loss: 0.0154
# Epoch [5/5], Step [1722/1912], Loss: 0.0866
# Epoch [5/5], Step [1723/1912], Loss: 0.0636
# Epoch [5/5], Step [1724/1912], Loss: 0.0017
# Epoch [5/5], Step [1725/1912], Loss: 0.0014
# Epoch [5/5], Step [1726/1912], Loss: 0.0015
# Epoch [5/5], Step [1727/1912], Loss: 0.0016
# Epoch [5/5], Step [1728/1912], Loss: 0.0015
# Epoch [5/5], Step [1729/1912], Loss: 0.3213
# Epoch [5/5], Step [1730/1912], Loss: 0.0015
# Epoch [5/5], Step [1731/1912], Loss: 0.0020
# Epoch [5/5], Step [1732/1912], Loss: 0.0016
# Epoch [5/5], Step [1733/1912], Loss: 0.0018
# Epoch [5/5], Step [1734/1912], Loss: 0.0015
# Epoch [5/5], Step [1735/1912], Loss: 0.0014
# Epoch [5/5], Step [1736/1912], Loss: 0.0017
# Epoch [5/5], Step [1737/1912], Loss: 0.0359
# Epoch [5/5], Step [1738/1912], Loss: 0.0018
# Epoch [5/5], Step [1739/1912], Loss: 0.0098
# Epoch [5/5], Step [1740/1912], Loss: 0.0014
# Epoch [5/5], Step [1741/1912], Loss: 0.0015
# Epoch [5/5], Step [1742/1912], Loss: 0.0016
# Epoch [5/5], Step [1743/1912], Loss: 0.0974
# Epoch [5/5], Step [1744/1912], Loss: 0.0015
# Epoch [5/5], Step [1745/1912], Loss: 0.0013
# Epoch [5/5], Step [1746/1912], Loss: 0.0113
# Epoch [5/5], Step [1747/1912], Loss: 0.0018
# Epoch [5/5], Step [1748/1912], Loss: 0.0055
# Epoch [5/5], Step [1749/1912], Loss: 0.0022
# Epoch [5/5], Step [1750/1912], Loss: 0.0014
# Epoch [5/5], Step [1751/1912], Loss: 0.0018
# Epoch [5/5], Step [1752/1912], Loss: 0.0015
# Epoch [5/5], Step [1753/1912], Loss: 0.0114
# Epoch [5/5], Step [1754/1912], Loss: 0.0129
# Epoch [5/5], Step [1755/1912], Loss: 0.0020
# Epoch [5/5], Step [1756/1912], Loss: 0.0312
# Epoch [5/5], Step [1757/1912], Loss: 0.0015
# Epoch [5/5], Step [1758/1912], Loss: 2.3309
# Epoch [5/5], Step [1759/1912], Loss: 0.0321
# Epoch [5/5], Step [1760/1912], Loss: 0.0019
# Epoch [5/5], Step [1761/1912], Loss: 0.0017
# Epoch [5/5], Step [1762/1912], Loss: 0.0023
# Epoch [5/5], Step [1763/1912], Loss: 0.0025
# Epoch [5/5], Step [1764/1912], Loss: 0.0139
# Epoch [5/5], Step [1765/1912], Loss: 0.1640
# Epoch [5/5], Step [1766/1912], Loss: 0.0020
# Epoch [5/5], Step [1767/1912], Loss: 0.0023
# Epoch [5/5], Step [1768/1912], Loss: 0.0394
# Epoch [5/5], Step [1769/1912], Loss: 0.0028
# Epoch [5/5], Step [1770/1912], Loss: 0.0108
# Epoch [5/5], Step [1771/1912], Loss: 0.0027
# Epoch [5/5], Step [1772/1912], Loss: 0.0108
# Epoch [5/5], Step [1773/1912], Loss: 0.0029
# Epoch [5/5], Step [1774/1912], Loss: 0.0128
# Epoch [5/5], Step [1775/1912], Loss: 0.0046
# Epoch [5/5], Step [1776/1912], Loss: 0.2509
# Epoch [5/5], Step [1777/1912], Loss: 0.0067
# Epoch [5/5], Step [1778/1912], Loss: 0.0121
# Epoch [5/5], Step [1779/1912], Loss: 0.0365
# Epoch [5/5], Step [1780/1912], Loss: 0.0029
# Epoch [5/5], Step [1781/1912], Loss: 0.0043
# Epoch [5/5], Step [1782/1912], Loss: 0.0025
# Epoch [5/5], Step [1783/1912], Loss: 0.0082
# Epoch [5/5], Step [1784/1912], Loss: 0.0392
# Epoch [5/5], Step [1785/1912], Loss: 0.0027
# Epoch [5/5], Step [1786/1912], Loss: 0.0027
# Epoch [5/5], Step [1787/1912], Loss: 0.0036
# Epoch [5/5], Step [1788/1912], Loss: 0.0029
# Epoch [5/5], Step [1789/1912], Loss: 0.6157
# Epoch [5/5], Step [1790/1912], Loss: 0.0019
# Epoch [5/5], Step [1791/1912], Loss: 0.0090
# Epoch [5/5], Step [1792/1912], Loss: 0.1892
# Epoch [5/5], Step [1793/1912], Loss: 0.0037
# Epoch [5/5], Step [1794/1912], Loss: 0.0019
# Epoch [5/5], Step [1795/1912], Loss: 0.0047
# Epoch [5/5], Step [1796/1912], Loss: 0.0020
# Epoch [5/5], Step [1797/1912], Loss: 0.0377
# Epoch [5/5], Step [1798/1912], Loss: 0.0087
# Epoch [5/5], Step [1799/1912], Loss: 0.0018
# Epoch [5/5], Step [1800/1912], Loss: 0.2153
# Epoch [5/5], Step [1801/1912], Loss: 0.0016
# Epoch [5/5], Step [1802/1912], Loss: 0.0019
# Epoch [5/5], Step [1803/1912], Loss: 0.0177
# Epoch [5/5], Step [1804/1912], Loss: 1.7090
# Epoch [5/5], Step [1805/1912], Loss: 0.0024
# Epoch [5/5], Step [1806/1912], Loss: 0.0015
# Epoch [5/5], Step [1807/1912], Loss: 0.3558
# Epoch [5/5], Step [1808/1912], Loss: 0.0022
# Epoch [5/5], Step [1809/1912], Loss: 0.4829
# Epoch [5/5], Step [1810/1912], Loss: 0.0015
# Epoch [5/5], Step [1811/1912], Loss: 0.0028
# Epoch [5/5], Step [1812/1912], Loss: 0.0020
# Epoch [5/5], Step [1813/1912], Loss: 0.0450
# Epoch [5/5], Step [1814/1912], Loss: 0.0085
# Epoch [5/5], Step [1815/1912], Loss: 0.0103
# Epoch [5/5], Step [1816/1912], Loss: 0.0014
# Epoch [5/5], Step [1817/1912], Loss: 0.0047
# Epoch [5/5], Step [1818/1912], Loss: 0.2387
# Epoch [5/5], Step [1819/1912], Loss: 0.0051
# Epoch [5/5], Step [1820/1912], Loss: 0.0017
# Epoch [5/5], Step [1821/1912], Loss: 0.0017
# Epoch [5/5], Step [1822/1912], Loss: 0.0137
# Epoch [5/5], Step [1823/1912], Loss: 0.0040
# Epoch [5/5], Step [1824/1912], Loss: 0.0022
# Epoch [5/5], Step [1825/1912], Loss: 0.0185
# Epoch [5/5], Step [1826/1912], Loss: 0.0012
# Epoch [5/5], Step [1827/1912], Loss: 0.4141
# Epoch [5/5], Step [1828/1912], Loss: 0.0016
# Epoch [5/5], Step [1829/1912], Loss: 0.0022
# Epoch [5/5], Step [1830/1912], Loss: 0.0972
# Epoch [5/5], Step [1831/1912], Loss: 0.0011
# Epoch [5/5], Step [1832/1912], Loss: 0.0157
# Epoch [5/5], Step [1833/1912], Loss: 0.0012
# Epoch [5/5], Step [1834/1912], Loss: 0.0370
# Epoch [5/5], Step [1835/1912], Loss: 0.0014
# Epoch [5/5], Step [1836/1912], Loss: 0.0012
# Epoch [5/5], Step [1837/1912], Loss: 0.0342
# Epoch [5/5], Step [1838/1912], Loss: 0.0083
# Epoch [5/5], Step [1839/1912], Loss: 0.0639
# Epoch [5/5], Step [1840/1912], Loss: 0.0130
# Epoch [5/5], Step [1841/1912], Loss: 0.0013
# Epoch [5/5], Step [1842/1912], Loss: 0.1905
# Epoch [5/5], Step [1843/1912], Loss: 0.1002
# Epoch [5/5], Step [1844/1912], Loss: 0.0048
# Epoch [5/5], Step [1845/1912], Loss: 0.1424
# Epoch [5/5], Step [1846/1912], Loss: 0.0010
# Epoch [5/5], Step [1847/1912], Loss: 0.0340
# Epoch [5/5], Step [1848/1912], Loss: 0.0011
# Epoch [5/5], Step [1849/1912], Loss: 0.0011
# Epoch [5/5], Step [1850/1912], Loss: 1.6071
# Epoch [5/5], Step [1851/1912], Loss: 0.0011
# Epoch [5/5], Step [1852/1912], Loss: 0.0012
# Epoch [5/5], Step [1853/1912], Loss: 0.2539
# Epoch [5/5], Step [1854/1912], Loss: 0.0014
# Epoch [5/5], Step [1855/1912], Loss: 0.0013
# Epoch [5/5], Step [1856/1912], Loss: 0.1206
# Epoch [5/5], Step [1857/1912], Loss: 0.0011
# Epoch [5/5], Step [1858/1912], Loss: 0.0165
# Epoch [5/5], Step [1859/1912], Loss: 0.0026
# Epoch [5/5], Step [1860/1912], Loss: 0.1299
# Epoch [5/5], Step [1861/1912], Loss: 0.0016
# Epoch [5/5], Step [1862/1912], Loss: 0.2675
# Epoch [5/5], Step [1863/1912], Loss: 0.0010
# Epoch [5/5], Step [1864/1912], Loss: 1.4872
# Epoch [5/5], Step [1865/1912], Loss: 0.0013
# Epoch [5/5], Step [1866/1912], Loss: 0.0011
# Epoch [5/5], Step [1867/1912], Loss: 0.0010
# Epoch [5/5], Step [1868/1912], Loss: 0.0012
# Epoch [5/5], Step [1869/1912], Loss: 0.0014
# Epoch [5/5], Step [1870/1912], Loss: 0.0011
# Epoch [5/5], Step [1871/1912], Loss: 0.0289
# Epoch [5/5], Step [1872/1912], Loss: 0.7589
# Epoch [5/5], Step [1873/1912], Loss: 0.0326
# Epoch [5/5], Step [1874/1912], Loss: 0.0011
# Epoch [5/5], Step [1875/1912], Loss: 0.0186
# Epoch [5/5], Step [1876/1912], Loss: 0.0009
# Epoch [5/5], Step [1877/1912], Loss: 0.0011
# Epoch [5/5], Step [1878/1912], Loss: 0.1556
# Epoch [5/5], Step [1879/1912], Loss: 0.0010
# Epoch [5/5], Step [1880/1912], Loss: 0.0253
# Epoch [5/5], Step [1881/1912], Loss: 0.0939
# Epoch [5/5], Step [1882/1912], Loss: 0.0011
# Epoch [5/5], Step [1883/1912], Loss: 0.0183
# Epoch [5/5], Step [1884/1912], Loss: 0.0138
# Epoch [5/5], Step [1885/1912], Loss: 3.4521
# Epoch [5/5], Step [1886/1912], Loss: 0.0012
# Epoch [5/5], Step [1887/1912], Loss: 0.0011
# Epoch [5/5], Step [1888/1912], Loss: 0.0054
# Epoch [5/5], Step [1889/1912], Loss: 0.0011
# Epoch [5/5], Step [1890/1912], Loss: 0.0486
# Epoch [5/5], Step [1891/1912], Loss: 0.0009
# Epoch [5/5], Step [1892/1912], Loss: 0.4362
# Epoch [5/5], Step [1893/1912], Loss: 0.1207
# Epoch [5/5], Step [1894/1912], Loss: 0.0302
# Epoch [5/5], Step [1895/1912], Loss: 2.4711
# Epoch [5/5], Step [1896/1912], Loss: 0.3276
# Epoch [5/5], Step [1897/1912], Loss: 0.0013
# Epoch [5/5], Step [1898/1912], Loss: 0.4577
# Epoch [5/5], Step [1899/1912], Loss: 0.0018
# Epoch [5/5], Step [1900/1912], Loss: 0.0015
# Epoch [5/5], Step [1901/1912], Loss: 1.9363
# Epoch [5/5], Step [1902/1912], Loss: 0.0043
# Epoch [5/5], Step [1903/1912], Loss: 0.0751
# Epoch [5/5], Step [1904/1912], Loss: 0.0048
# Epoch [5/5], Step [1905/1912], Loss: 0.0124
# Epoch [5/5], Step [1906/1912], Loss: 1.1652
# Epoch [5/5], Step [1907/1912], Loss: 0.3316
# Epoch [5/5], Step [1908/1912], Loss: 0.0050
# Epoch [5/5], Step [1909/1912], Loss: 0.2153
# Epoch [5/5], Step [1910/1912], Loss: 0.0331
# Epoch [5/5], Step [1911/1912], Loss: 0.3594
# Epoch [5/5], Step [1912/1912], Loss: 0.0205
# Validation Metrics [Epoch 5]:Accuracy: 0.9059, Precision: 0.7981, Recall: 0.9884, F1 Score: 0.8831

# %%
model.eval()
val_preds = []
val_targets = []
with torch.no_grad():
    for images, labels in val_loader:
        images = images.cuda()
        labels = labels.cuda()
        outputs = model(images)
        preds = (outputs > 0.5).float()
        val_preds.extend(preds.cpu().numpy())
        val_targets.extend(labels.cpu().numpy())

acc = accuracy_score(val_targets, val_preds)
prec = precision_score(val_targets, val_preds, zero_division=0)
rec = recall_score(val_targets, val_preds, zero_division=0)
f1 = f1_score(val_targets, val_preds, zero_division=0)

print(f"Validation Metrics:Accuracy: {acc:.4f}Precision: {prec:.4f}Recall: {rec:.4f}F1 Score: {f1:.4f}")


acc = accuracy_score(targets, predictions)
prec = precision_score(targets, predictions, zero_division=0)
rec = recall_score(targets, predictions, zero_division=0)
f1 = f1_score(targets, predictions, zero_division=0)

print(f"Evaluation Metrics:Accuracy: {acc:.4f}Precision: {prec:.4f}Recall: {rec:.4f}F1 Score: {f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 val_targets = []
#       4 with torch.no_grad():
# ----> 5     for images, labels in val_loader:
#       6         images = images.cuda()
#       7         labels = labels.cuda()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[2], line 14, in MRIDataset.__getitem__(self, idx)
#      12 def __getitem__(self, idx):
#      13     img_path = self.image_paths[idx]
# ---> 14     img = nib.load(img_path).get_fdata().astype(np.float32)
#      15     img = (img - np.min(img)) / (np.max(img) - np.min(img) + 1e-8)  # normalize
#      16     img = np.expand_dims(img, axis=0)  # [C, D, H, W]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nibabel\dataobj_images.py:374, in DataobjImage.get_fdata(self, caching, dtype)
#     370         return self._fdata_cache
#     371 # Always return requested data type
#     372 # For array proxies, will attempt to confine data array to dtype
#     373 # during scaling
# --> 374 data = np.asanyarray(self._dataobj, dtype=dtype)
#     375 if caching == 'fill':
#     376     self._fdata_cache = data
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nibabel\arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
#     433 def __array__(self, dtype=None):
#     434     """Read data from file and apply scaling, casting to ``dtype``
#     435
#     436     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)    452         Scaled image data with type `dtype`.
#     453     """
# --> 454     arr = self._get_scaled(dtype=dtype, slicer=())
#     455     if dtype is not None:
#     456         arr = arr.astype(dtype, copy=False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nibabel\arrayproxy.py:421, in ArrayProxy._get_scaled(self, dtype, slicer)
#     419     scl_inter = scl_inter.astype(use_dtype)
#     420 # Read array and upcast as necessary for big slopes, intercepts
# --> 421 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     422 if dtype is not None:
#     423     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nibabel\arrayproxy.py:391, in ArrayProxy._get_unscaled(self, slicer)
#     387 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     388     (), self._shape, False
#     389 ):
#     390     with self._get_fileobj() as fileobj, self._lock:
# --> 391         return array_from_file(
#     392             self._shape,
#     393             self._dtype,
#     394             fileobj,
#     395             offset=self._offset,
#     396             order=self.order,
#     397             mmap=self._mmap,
#     398         )
#     399 with self._get_fileobj() as fileobj:
#     400     return fileslice(
#     401         fileobj,
#     402         slicer,
#    (...)    407         lock=self._lock,
#     408     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nibabel\volumeutils.py:467, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     465 if hasattr(infile, 'readinto'):
#     466     data_bytes = bytearray(n_bytes)
# --> 467     n_read = infile.readinto(data_bytes)
#     468     needs_copy = False
#     469 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\gzip.py:326, in GzipFile.read(self, size)
#     324     import errno
#     325     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 326 return self._buffer.read(size)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\gzip.py:552, in _GzipReader.read(self, size)
#     548     if buf == b"":
#     549         raise EOFError("Compressed file ended before the "
#     550                        "end-of-stream marker was reached")
# --> 552 self._crc = zlib.crc32(uncompress, self._crc)
#     553 self._stream_size += len(uncompress)
#     554 self._pos += len(uncompress)
#
# KeyboardInterrupt:

# %%
# Plot training and validation F1-score
train_f1s = [t[3] for t in train_history]
val_f1s = [v[3] for v in val_history]

plt.figure(figsize=(10, 5))
plt.plot(train_f1s, label='Train F1')
plt.plot(val_f1s, label='Val F1')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('Training vs Validation F1 Score')
plt.legend()
plt.grid(True)
plt.savefig("f1_score_plot.png")
plt.show()

# Test set evaluation
model.eval()
test_preds = []
test_targets = []
with torch.no_grad():
    for images, labels in test_loader:
        images = images.cuda()
        labels = labels.cuda()
        outputs = model(images)
        preds = (outputs > 0.5).float()
        test_preds.extend(preds.cpu().numpy())
        test_targets.extend(labels.cpu().numpy())

# Confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(test_targets, test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Negative", "Positive"])
disp.plot(cmap='Blues')
plt.title("Confusion Matrix - Test Set")
plt.savefig("confusion_matrix_face_fatures.png")
plt.show()

acc = accuracy_score(test_targets, test_preds)
prec = precision_score(test_targets, test_preds, zero_division=0)
rec = recall_score(test_targets, test_preds, zero_division=0)
f1 = f1_score(test_targets, test_preds, zero_division=0)

print(f"Test Set Metrics:Accuracy: {acc:.4f}Precision: {prec:.4f}Recall: {rec:.4f}F1 Score: {f1:.4f}")

# Save the trained model
torch.save(model.state_dict(), "resnet3d_model.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 32
#       1 # # Plot training and validation F1-score
#       2 # train_f1s = [t[3] for t in train_history]
#       3 # val_f1s = [v[3] for v in val_history]
#    (...)     28
#      29 # Confusion matrix
#      30 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# ---> 32 cm = confusion_matrix(test_targets, test_preds)
#      33 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Negative", "Positive"])
#      34 disp.plot(cmap='Blues')
#
# NameError: name 'test_targets' is not defined

# %%
def run_gradcam(model, sample_img, target_layer):
    import torch.nn.functional as F
    from scipy.ndimage import zoom
    import numpy as np

    input_tensor = sample_img.unsqueeze(0).cuda().requires_grad_(True)

    class FeatureExtractor:
        def __init__(self, model, target_layer):
            self.model = model
            self.target_layer = target_layer
            self.gradients = None
            self.activations = None
            self.hook()

        def hook(self):
            def forward_hook(module, input, output):
                self.activations = output.detach()
            def backward_hook(module, grad_input, grad_output):
                self.gradients = grad_output[0].detach()
            self.target_layer.register_forward_hook(forward_hook)
            self.target_layer.register_backward_hook(backward_hook)

    # Register hooks and run forward/backward pass
    target = FeatureExtractor(model, target_layer)
    output = model(input_tensor)
    model.zero_grad()
    output.backward()

    # Compute Grad-CAM
    weights = target.gradients.mean(dim=(2, 3, 4), keepdim=True)
    cam = F.relu((weights * target.activations).sum(1)).squeeze().cpu().numpy()
    cam = (cam - cam.min()) / (cam.max() - cam.min() + 1e-8)

    # Resize CAM to match input shape
    original_shape = sample_img.squeeze().cpu().numpy().shape
    cam_resized = zoom(cam, np.array(original_shape) / np.array(cam.shape), order=1)

    return cam_resized

def plot_multiview_overlay(original_img, cam, output_file):
    axial = min(cam.shape[0] - 1, original_img.shape[0] // 2)
    coronal = min(cam.shape[1] - 1, original_img.shape[1] // 2)
    sagittal = min(cam.shape[2] - 1, original_img.shape[2] // 2)

    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    axs[0].imshow(original_img[:, axial, :], cmap='gray')
    axs[0].imshow(cam[axial], cmap='hot', alpha=0.5)
    axs[0].set_title("Axial")

    axs[1].imshow(original_img[coronal], cmap='gray')
    axs[1].imshow(cam[:, coronal, :], cmap='hot', alpha=0.5)
    axs[1].set_title("Coronal")

    axs[2].imshow(original_img[:, :, sagittal], cmap='gray')
    axs[2].imshow(cam[:, :, sagittal], cmap='hot', alpha=0.5)
    axs[2].set_title("Sagittal")

    plt.suptitle(output_file)
    plt.tight_layout()
    plt.savefig(output_file)
    plt.show()

# %%
# Facial feature detection model
model_face = ResNet3D()
model_face.load_state_dict(torch.load("best_resnet3d_model.pt"))
model_face.eval()

# Brain tissue loss detection model
model_tissue = ResNet3D()
model_tissue.load_state_dict(torch.load("resnet3d_brain_tissue_model.pt"))
model_tissue.eval()

sample_img, _ = test_dataset[12] # 4, 8
original = sample_img.squeeze().cpu().numpy()

# Grad-CAM for facial feature model
cam_face = run_gradcam(model_face.cuda(), sample_img, model_face.layer4[-1].conv2)
plot_multiview_overlay(original, cam_face, "gradcam_face_multiview.png")

# Grad-CAM for tissue loss model
cam_tissue = run_gradcam(model_tissue.cuda(), sample_img, model_tissue.layer4[-1].conv2)
plot_multiview_overlay(original, cam_tissue, "gradcam_tissue_multiview.png")
